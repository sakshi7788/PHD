# %%
import numpy as np
import numpy.random as rand
from sklearn.metrics import silhouette_score
import copy
import pandas as pd
import matplotlib.pyplot as plt
from numpy import savetxt
from sklearn.metrics.cluster import homogeneity_score
from sklearn.metrics.cluster import rand_score
from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import completeness_score
from csv import writer

# %%
filename="xml_modified_output.npy"
p1=[[14,10],[14,20],[15,20],[15,30],[15,50],[16,30],[17,40],[17,50],[16,60],[17,70]]

# %%
from sklearn.cluster import KMeans
def K_means_clustering(datapoint,s):
    a=s
    v=np.array(a)
    x=v.reshape(4,18)
    km=KMeans(n_clusters=4,init=x, n_init=1)
    km.fit(datapoint)
    score = silhouette_score(datapoint, km.labels_, metric='euclidean')
    print("silhouette score is",score)
    def ClusterIndicesNumpy(clustNum, labels_array):
        return np.where(labels_array == clustNum)[0]
    cluster_1_records=datapoint[ClusterIndicesNumpy(0,km.labels_)]
    cluster_2_records=datapoint[ClusterIndicesNumpy(1,km.labels_)]
    cluster_3_records=datapoint[ClusterIndicesNumpy(2,km.labels_)]
    cluster_4_records=datapoint[ClusterIndicesNumpy(3,km.labels_)]

    return [cluster_1_records,cluster_2_records,cluster_3_records,cluster_4_records]

# %%
def fitnes_function(position):
    #Pass only position , pass data-set and then generate 
    #fitness_value=0.0
    x,y,z,w=K_means_clustering(df,position)
    fitness_value_x=intra_cluster(x)
    print("x",fitness_value_x)
    fitness_value_y=intra_cluster(y)
    fitness_value_z=intra_cluster(z)
    print("y",fitness_value_y)
    print("z",fitness_value_z)
    
    fitness_value=float(np.asarray(fitness_value_x))+float(np.asarray(fitness_value_y))+float(np.asarray(fitness_value_z))
    print("final",fitness_value)
    return fitness_value

# %%
#pos:mean of the cluster
def intra_cluster(data_point):
    import numpy as np
    c=data_point
    #print("shape of data vector is",c.shape)
    e=c.transpose()
    #print(e.shape)
    m,n=e.shape
    #print(m)
    #print(n)
    #mean_c=e.mean()
    #print("mean of the cluster is",mean_c)
    #print("shape of the mean of the cluster is",mean_c.shape)
    s1=0
    #mean_cluster=0
    total_sum_data_vector=0
    for x in range(0,n):
        p=c[:][x]
        #print(p.shape)
        data_vector=p.reshape(m,1)
        #print("shape of data point of cluster",data_vector.shape)
        total_sum_data_vector+=data_vector
        #print("total sum of individual data vectors",total_sum_data_vector)
        #print("shape of total sum of individual data vectors",total_sum_data_vector.shape)
        mean_cluster=total_sum_data_vector/n
        #print("mean of each cluster",mean_cluster)
    for x in range(0,n):
        p=c[:][x]
        #print(p.shape)
        data_vector=p.reshape(m,1)
        #print("shape of data point of cluster",data_vector.shape)
        diff=(data_vector-mean_cluster)
        #print("difference of data point with cluster difference",diff.shape)
        s1+=np.dot(diff,diff.transpose())
        #print(s1)
    #print("shape of within cluster distance matrix",s1.shape)
    #print("final within cluster distance matrix",s1.shape)
    #print("sum of intra cluster distance that is Sw is",s1.trace())
    within=s1.trace()
    intra=within.reshape(1,1)
    inter=inter_cluster(data_point)
    res=within/inter
    #print("ratio of trace is",res)
    print("intra",float(np.asarray(res)))
    return [float(np.asarray(res))]

# %%
def inter_cluster(data_point):
    total_sum_data_vector=0
    c=data_point
    s1=0
    #print("shape of data vector of individual cluster is",c.shape)
    m,n=c.shape
    #print(m)
    #print(n)
    f=c.transpose()
    #print(f.shape)
    for x in range(0,n):
        p=f[:][x]
        #print(p.shape)
        data_vector=p.reshape(m,1)
        #print("shape of data point of cluster",data_vector.shape)
        total_sum_data_vector+=data_vector
        #print("total sum of individual data vectors",total_sum_data_vector)
        #print("shape of total sum of individual data vectors",total_sum_data_vector.shape)
        mean_cluster=total_sum_data_vector/n
        #print("mean of each cluster",mean_cluster)
        #print("mean of each cluster shape",mean_cluster.shape)
        mean_overall_cluster=data_point/m*n
        
        diff=(mean_cluster-mean_overall_cluster)
        #print("difference of individual cluster with overall difference",diff.shape)
        s1+=np.dot(diff,diff.transpose())
        #print(s1)
        #print("shape of within cluster distance matrix",s1.shape)
        #print("final inter cluster distance matrix",s1.shape)
    #print("sum of inter cl uster distance that is Sb is",s1.trace())
        #print(s1.trace().shape)
    inter=s1.trace()
    inter.reshape(1,1)
    #return[inter]
    print("inter",float(np.asarray(inter)))
    return[float(np.asarray(inter))]

# %%
# wolf class
class wolf:
    import numpy.random as rand
    def __init__(self, fitness, dim,seed):
        
        #self.position=[0.0 for i in range(dim)]
        #print(self.position)
        
        index=rand.randint(16,size=4)
        value=df[index]
        print(value)
        
        a=value.flatten()
        print(a)
        
        '''for x in b:
            for val in x:
                b.append(val)'''
                
        self.position=a
        
        self.fitness = fitness(self.position)
        print("fitness is",self.fitness)

# %%
import numpy as np
import random

def gwo(fitness, max_iter, n, dim):
    rnd = random.Random(0)
    
    # create n random wolves
    population = [ wolf(fitness, dim,i) for i in range(n)]
    print("printing population",population[0].position)
    
    # On the basis of fitness values of wolves
    # sort the population in asc order
    
    population = sorted(population, key = lambda temp: temp.fitness)
    
    
 
    # best 3 solutions will be called as
    # alpha, beta and gaama
    alpha_wolf, beta_wolf, gamma_wolf = copy.copy(population[: 3])
    print("alpha is",alpha_wolf.position)
    print("beta wolf is",beta_wolf.position)
    print("gamma wolf is",gamma_wolf.position)
    
    
    Iter = 0
    while Iter < max_iter:
         
        
 
        # linearly decreased from 2 to 0
        a = 2*(1 - Iter/max_iter)
 
        # updating each population member with the help of best three members
        for i in range(n):
            
            print("poulation is",population[i].position)
            A1, A2, A3 = a * (2 * rnd.random() - 1), a * (
              2 * rnd.random() - 1), a * (2 * rnd.random() - 1)
            C1, C2, C3 = 2 * rnd.random(), 2*rnd.random(), 2*rnd.random()
            
            
            X1 = [0.0 for i in range(dim)]
            X2 = [0.0 for i in range(dim)]
            X3 = [0.0 for i in range(dim)]
            Xnew = [0.0 for i in range(dim)]
            print("Type of Xnew",type(Xnew))
            
            
            for j in range(dim):
                print("alpha type",type(alpha_wolf.position[j]))
                print("population",population[i].position[j])
                print("alpha",(alpha_wolf.position[j]))
                print("population type",type(population[i].position[j]))
                
                X1[j] = alpha_wolf.position[j] - A1 * abs(
                  C1*alpha_wolf.position[j] - population[i].position[j])
                X2[j] = beta_wolf.position[j] - A2 * abs(
                  C2 *beta_wolf.position[j] - population[i].position[j])
                X3[j] = gamma_wolf.position[j] - A3 * abs(
                  C3*gamma_wolf.position[j] - population[i].position[j])
                Xnew[j]+= X1[j] + X2[j] + X3[j]
                
            for j in range(dim):
                Xnew[j]/=3.0
             

            # fitness calculation of new solution
            fnew = fitness(Xnew)
 
            # greedy selection
            if fnew < population[i].fitness:
                population[i].position = Xnew
                population[i].fitness = fnew
                
        # On the basis of fitness values of wolves
        # sort the population in asc order
        population = sorted(population, key = lambda temp: temp.fitness)
 
        # best 3 solutions will be called as
        # alpha, beta and gaama
        alpha_wolf, beta_wolf, gamma_wolf = copy.copy(population[: 3])
        print("Iteration number is",Iter)
        Iter+= 1
    # end-while
 
    # returning the best solution
    return alpha_wolf.position
           
#----------------------------

# %%
for i in range(0,10):
  df= np.loadtxt(r"%s"%(filename))
  df=np.nan_to_num(df, nan=0)
  parameter1=p1[i][0];
  parameter2=p1[i][1];
  Arr=np.zeros(df.shape[0])
  Dolphin1=[50,35,13,39,59,4,15,21,9,31,60,48,37,1,46,16,24,16,29,19,41,56,12,52,5,38,22,30,54,44,36,17,45,53,34,15,43,11,46,15]
  Dolphin2=[49,58,6,10,14,55,57,20,2,7,18,23,61,32,42,28,8,27,26]
  Karate1=[13,20,5,6,1,4,3,17,7,11,12,22,18,8,2,14]
  Karate2=[29,32,25,28,26,24,27,30,10,34,9,33,19,31,21,16,23,15]
  Polbooks1=[17,16,38,39,37,44,26,18,14,45,30,33,3,2,6,57,23,53,59,78,25,50,56,20,35,40,42,55,36,43,28,24,9,12,13,34,27,22,46,58,48,40,15,51,54,21,46]
  Polbooks2=[77,8,7,1,104,105,47,5,49,29,19,52,70]
  Polbooks3=[99,93,79,32,76,84,92,88,101,63,91,82,80,83,72,98,85,75,83,72,64,61,100,74,73,31,86,60,97,87,71,67,69,102,90,89,94,81,65,62,96,95,68,103,66]
  Highland1=[0,1,12,14]
  Highland2=[13,8,9,12,4]
  Highland3=[6,7,3,2,5,11,10]
  XML1=[17,16,15]
  XML2=[14,6,0]
  XML3=[12,10,8,7,13,9,11]
  XML4=[4,5,3,2,1]
  for i in range(df.shape[0]):
     if(i in XML1):
       Arr[i]=1;
     elif(i in XML2):
       Arr[i]=2;
     elif(i in XML3):
       Arr[i]=3
     elif(i in XML4):
       Arr[i]=4
  df2=pd.DataFrame(Arr);
  dim =72;
  fitness =fitnes_function
  num_particles =10
  max_iter =parameter2
  best_position =gwo(fitness, max_iter, num_particles, dim)
  a=best_position
  v=np.array(a)
  x=v.reshape(4,18)

  km=KMeans(n_clusters=4,init=x, n_init=1)
  d=km.fit_predict(df)
  score = silhouette_score(df, km.labels_, metric='euclidean')





  #print(["%.6f"%best_position[k] for k in range(dim)])
  err = fitness(best_position)
  #print("fitness of best solution",err)
  df1 = pd.DataFrame(d);
  df = pd.DataFrame(df);
  df["Predicted"]=df1.values
  df["Actual"]=df2.values
  

  List=[parameter1,parameter2,"%s"%(filename),"after",completeness_score(d,Arr),homogeneity_score(d, Arr),rand_score(d, Arr),normalized_mutual_info_score(d, Arr)]
  with open('GGWWOO.csv', 'a') as f_object:

    writer_object = writer(f_object)
    writer_object.writerow(List)
    f_object.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# alpha type <class 'numpy.float64'>
# population 1.351383050868092
# alpha 1.2302004813769989
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.7371302774201741
# alpha -0.6102632295215338
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -3.5728327244965254
# alpha -2.953919724189778
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 8.606296058828049
# alpha 8.141426497651215
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.0
# alpha 0.0
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.03282319484921938
# alpha -0.027168698443166734
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.005220204572433586
# alpha -0.004763014097263007
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.02463396667038741
# alpha -0.020290643103540756
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.032046441413550536
# alpha -0.026537209359095856
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.02567309908984107
# alpha -0.02122925835411803
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.03423576086029125
# alpha -0.028419271460322044
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.026593185870408625
# alpha -0.024935975343996237
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.02116112865517422
# alpha -0.01871573869194789
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0

# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.013926531268055679
# alpha -0.013772898199169858
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.045800803218895424
# alpha -0.043010824477853794
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.15934853305282695
# alpha 0.1548590687393298
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.393200442430633
# alpha 0.38175573583350925
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.5478024117909472
# alpha -0.5170890901544758
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.8192018302702089
# alpha -1.713057328190774
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.1420832339510216
# alpha 1.1045266841055448
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.934205100015567
# alpha -0.8789139488392745
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -4.676777034441252
# alpha -4.473103086477189
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.0
# alpha 0.0
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.03170858437376365
# alpha -0.029898438973549313
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.04423480457949639
# alpha -0.04231330164879279
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.03472376414411544
# alpha -0.032204252748841374
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.0339638873542659
# alpha -0.03163633183490621
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.06547423370625273
# alpha 0.0636422051347485
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.000672448367366365
# alpha -0.0007837829296859334
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.027235029190107323
# alpha -0.025250682578189316
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.02024826575709576
# alpha -0.018762701132420474
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.022231414851116918
# alpha -0.02140554109997364
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.04745536799563597
# alpha -0.04466707422345336
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.2210798672067316
# alpha 0.21241250805408826
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.4641672916338491
# alpha 0.45472314971033595
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.017930634467138173
# alpha -0.007330997281755223
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.2692434563142212
# alpha 1.2302004813769989
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.6511801034907089
# alpha -0.6102632295215338
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -3.1514633605606037
# alpha -2.953919724189778
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 8.386148873082695
# alpha 8.141426497651215
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.0
# alpha 0.0
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.028954110098428344
# alpha -0.027168698443166734
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.005154157658079452
# alpha -0.004763014097263007
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.02176343754376378
# alpha -0.020290643103540756
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.02827593926242689
# alpha -0.026537209359095856
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.022645449529519815
# alpha -0.02122925835411803
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.03031544886121369
# alpha -0.028419271460322044
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.026826325365716552
# alpha -0.024935975343996237
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.02025105070922642
# alpha -0.01871573869194789
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.049111847486234116
# alpha 0.04750562747695311
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.02851259055801988
# alpha 0.028209758450185005
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.00025817067087670494
# alpha 0.0009554768471285408
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.4732670533145354
# alpha 0.46138374596749143
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.43920026792772066
# alpha 0.4150323330279335
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.6442184942363918
# alpha 0.6254993941233926
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 4.401095543363815
# alpha 4.270460653722346
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.543882271832949
# alpha 0.5219169088388044
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 4.159793848324246
# alpha 4.047312501020756
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.0
# alpha 0.0
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.030450514418054412
# alpha -0.028882885475912806
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.03691515535631022
# alpha -0.035075843564102184
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.021245684363783466
# alpha -0.020106813044241584
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.0426701869429092
# alpha 0.04150470760389679
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.038956003780664106
# alpha 0.037998437401840245
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.005911609262084182
# alpha -0.005579935443187481
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.028819638878726656
# alpha -0.026878386423203806
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.19381042363354237
# alpha 0.18720050799421384
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.14579223335009103
# alpha 0.14166215421177655
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.12908995838227658
# alpha -0.1220764614319496
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.17472465034137344
# alpha -0.16421737524619517
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.06141369070544871
# alpha -0.05793713774416396
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.3337063360931562
# alpha -0.31505595673500186
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.9469398554602995
# alpha -0.8911320202122713
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.5421450684662837
# alpha 0.5227366307439844
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.4396342773614956
# alpha 0.4190822321957664
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.8538884044559456
# alpha -1.7519711222815975
# population type <class 'numpy.float64'>
# silhouette score is 0.2350595700170309
# inter 171246.66970403912
# intra 0.00010829477388866592
# x [0.00010829477388866592]
# inter 337997.1634692785
# intra 0.0
# inter 63338.646001247296
# intra 8.61336757269715e-05
# y [0.0]
# z [8.61336757269715e-05]
# final 0.00019442844961563743
# Iteration number is 69
# silhouette score is 0.2350595700170309
# inter 171246.66970403912
# intra 0.00010829477388866592
# x [0.00010829477388866592]
# inter 337997.1634692785
# intra 0.0
# inter 63338.646001247296
# intra 8.61336757269715e-05
# y [0.0]
# z [8.61336757269715e-05]
# final 0.00019442844961563743
