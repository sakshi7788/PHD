# %%
import numpy as np
import numpy.random as rand
from sklearn.metrics import silhouette_score
import copy
import pandas as pd
import numpy as np
import random
import math    # cos() for Rastrigin
import copy    # array-copying convenience
import sys
import matplotlib.pyplot as plt
from numpy import savetxt
from sklearn.metrics.cluster import homogeneity_score
from sklearn.metrics.cluster import rand_score
from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import completeness_score
from csv import writer

# %%
filename="xml_modified_output.npy"
p1=[[14,10],[14,20],[15,20],[15,30],[15,50],[16,30],[17,40],[17,50],[16,60],[17,70]]

# %%
from sklearn.cluster import KMeans
def K_means_clustering(datapoint,s):
    a=s
    v=np.array(a)
    print(v.shape)
    x=v.reshape(4,18)
    km=KMeans(n_clusters=4,init=x, n_init=1)
    km.fit(datapoint)
    score = silhouette_score(datapoint, km.labels_, metric='euclidean')
    print("silhouette score is",score)
    def ClusterIndicesNumpy(clustNum, labels_array):
      return np.where(labels_array == clustNum)
    cluster_2_records=datapoint[ClusterIndicesNumpy(1,km.labels_)]
    cluster_1_records=datapoint[ClusterIndicesNumpy(0,km.labels_)]
    cluster_3_records=datapoint[ClusterIndicesNumpy(2,km.labels_)]
    cluster_4_records=datapoint[ClusterIndicesNumpy(3,km.labels_)]

    
    return [cluster_1_records,cluster_2_records,cluster_3_records,cluster_4_records]

# %%
def fitnes_function(position):
    #Pass only position , pass data-set and then generate 
    #fitness_value=0.0
    x,y,z,m=K_means_clustering(df,position)
    fitness_value_x=intra_cluster(x)
    print("x",fitness_value_x)
    fitness_value_y=intra_cluster(y)
    fitness_value_z=intra_cluster(z)
    fitness_value_m=intra_cluster(m)
    print("y",fitness_value_y)
    print("z",fitness_value_z)
    
    fitness_value=float(np.asarray(fitness_value_x))+float(np.asarray(fitness_value_y))+float(np.asarray(fitness_value_z))+float(np.asarray(fitness_value_m))
    #print("final",fitness_value)
    return fitness_value

# %%
#pos:mean of the cluster
def intra_cluster(data_point):
    import numpy as np
    c=data_point
    #print("shape of data vector is",c.shape)
    e=c.transpose()
    #print(e.shape)
    m,n=e.shape
    #print(m)
    #print(n)
    #mean_c=e.mean()
    #print("mean of the cluster is",mean_c)
    #print("shape of the mean of the cluster is",mean_c.shape)
    s1=0
    #mean_cluster=0
    total_sum_data_vector=0
    for x in range(0,n):
        p=c[:][x]
        #print(p.shape)
        data_vector=p.reshape(m,1)
        #print("shape of data point of cluster",data_vector.shape)
        total_sum_data_vector+=data_vector
        #print("total sum of individual data vectors",total_sum_data_vector)
        #print("shape of total sum of individual data vectors",total_sum_data_vector.shape)
        mean_cluster=total_sum_data_vector/n
        #print("mean of each cluster",mean_cluster)
    for x in range(0,n):
        p=c[:][x]
        #print(p.shape)
        data_vector=p.reshape(m,1)
        #print("shape of data point of cluster",data_vector.shape)
        diff=(data_vector-mean_cluster)
        #print("difference of data point with cluster difference",diff.shape)
        s1+=np.dot(diff,diff.transpose())
        #print(s1)
    #print("shape of within cluster distance matrix",s1.shape)
    #print("final within cluster distance matrix",s1.shape)
    #print("sum of intra cluster distance that is Sw is",s1.trace())
    within=s1.trace();
    intra=within.reshape(1,1)
    inter=inter_cluster(data_point)
    res=within/inter
    print("intra",float(np.asarray(res)))
    return [float(np.asarray(res))]

# %%
def inter_cluster(data_point):
    total_sum_data_vector=0
    c=data_point
    s1=0
    #print("shape of data vector of individual cluster is",c.shape)
    m,n=c.shape
    #print(m)
    #print(n)
    f=c.transpose()
    #print(f.shape)
    for x in range(0,n):
        p=f[:][x]
        #print(p.shape)
        data_vector=p.reshape(m,1)
        #print("shape of data point of cluster",data_vector.shape)
        total_sum_data_vector+=data_vector
        #print("total sum of individual data vectors",total_sum_data_vector)
        #print("shape of total sum of individual data vectors",total_sum_data_vector.shape)
        mean_cluster=total_sum_data_vector/n
        #print("mean of each cluster",mean_cluster)
        #print("mean of each cluster shape",mean_cluster.shape)
        mean_overall_cluster=data_point/m*n
        
        diff=(mean_cluster-mean_overall_cluster)
        #print("difference of individual cluster with overall difference",diff.shape)
        s1+=np.dot(diff,diff.transpose())
        #print(s1)
        #print("shape of within cluster distance matrix",s1.shape)
        #print("final inter cluster distance matrix",s1.shape)
    #print("sum of inter cluster distance that is Sb is",s1.trace())
        #print(s1.trace().shape)
    inter=s1.trace()
    inter.reshape(1,1)
    print("inter",float(np.asarray(inter)))
    return[float(np.asarray(inter))]

# %%
#Particle.py

# %%
#particle class
class Particle:
  def __init__(self, fitness, dim, minx, maxx, seed):
    self.rnd = random.Random(seed)
 
    # initialize position of the particle with 0.0 value
    #self.position = [0.0 for i in range(dim)]
 
     # initialize velocity of the particle with 0.0 value
    #self.velocity = [0.0 for i in range(dim)]
 
    # initialize best particle position of the particle with 0.0 value
    #self.best_part_pos = [0.0 for i in range(dim)]
     

    
    x=df.shape[0]-2
    index=rand.randint(parameter1,size=4)
    value=df[index]
    print(value)
        
    a=value.flatten()
    print(a)
        
    self.position=a
    print(self.position)
    self.velocity=a
    self.best_part_pos=a
    
    # loop dim times to calculate random position and velocity
    # range of position and velocity is [minx, max]
    #for i in range(dim):
     #index=self.rnd.random(16,size=3)
      #self.position[i] =df[index]
      
      #self.velocity[i] = ((maxx - minx) *
        #self.rnd.random() + minx)
 
    # compute fitness of particle
    self.fitness = fitness(self.position) # curr fitness
 
    # initialize best position and fitness of this particle
    self.best_part_pos = copy.copy(self.position)
    self.best_part_fitnessVal = self.fitness # best fitness

# %%
def pso(fitness, max_iter, n, dim, minx, maxx):
  # hyper parameters
  w = 0.729    # inertia
  c1 = 1.49445 # cognitive (particle)
  c2 = 1.49445 # social (swarm)
 
  rnd = random.Random(0)
 
  # create n random particles
  swarm = [Particle(fitness, dim, minx, maxx, i) for i in range(n)]
 
  # compute the value of best_position and best_fitness in swarm
  best_swarm_pos = [0.0 for i in range(dim)]
  best_swarm_fitnessVal = sys.float_info.max # swarm best
 
  # computer best particle of swarm and it's fitness
  for i in range(n): # check each particle
    print("swarm",swarm[i].fitness)
    if swarm[i].fitness < best_swarm_fitnessVal:
      best_swarm_fitnessVal = swarm[i].fitness
      best_swarm_pos = copy.copy(swarm[i].position)
 
  # main loop of pso
  Iter = 0
  while Iter < max_iter:
     
    # after every 10 iterations
    # print iteration number and best fitness value so far
    if Iter % 10 == 0 and Iter > 1:
      print("Iter = " + str(Iter) + " best fitness = %.3f" % best_swarm_fitnessVal)
 
    for i in range(n): # process each particle
       
      # compute new velocity of curr particle
      for k in range(dim):
        r1 = rnd.random()    # randomizations
        r2 = rnd.random()
     
        swarm[i].velocity[k] = (
                                 (w * swarm[i].velocity[k]) +
                                 (c1 * r1 * (swarm[i].best_part_pos[k] - swarm[i].position[k])) + 
                                 (c2 * r2 * (best_swarm_pos[k] -swarm[i].position[k]))
                               ) 
 
 
        # if velocity[k] is not in [minx, max]
        # then clip it
        if swarm[i].velocity[k] < minx:
          swarm[i].velocity[k] = minx
        elif swarm[i].velocity[k] > maxx:
          swarm[i].velocity[k] = maxx
 
 
      # compute new position using new velocity
      for k in range(dim):
        swarm[i].position[k] += swarm[i].velocity[k]
   
      # compute fitness of new position
      swarm[i].fitness = fitness(swarm[i].position)

      print("swarm ",swarm[i].fitness)
 
      # is new position a new best for the particle?
      if swarm[i].fitness < swarm[i].best_part_fitnessVal:
        swarm[i].best_part_fitnessVal = swarm[i].fitness
        swarm[i].best_part_pos = copy.copy(swarm[i].position)
 
      # is new position a new best overall?
      if swarm[i].fitness < best_swarm_fitnessVal:
        best_swarm_fitnessVal = swarm[i].fitness
        best_swarm_pos = copy.copy(swarm[i].position)
     
    # for-each particle
    Iter += 1
  #end_while
  return best_swarm_pos
# end pso

# %%
for i in range(0,10):
  df= np.loadtxt(r"%s"%(filename))
  df=np.nan_to_num(df, nan=0)
  parameter1=p1[i][0];
  parameter2=p1[i][1];
  Arr=np.zeros(df.shape[0])
  XML1=[17,16,15]
  XML2=[14,6,0]
  XML3=[12,10,8,7,13,9,11]
  XML4=[4,5,3,2,1]
  for i in range(df.shape[0]):
     if(i in XML1):
       Arr[i]=1;
     elif(i in XML2):
       Arr[i]=2;
     elif(i in XML3):
       Arr[i]=3
     elif(i in XML4):
       Arr[i]=4
  df2=pd.DataFrame(Arr);
  df2.shape[0]
  dim =72
  fitness =fitnes_function
  num_particles =10
  max_iter =parameter2
  best_position = pso(fitness, max_iter, num_particles, dim, -10.0, 10.0)
 

  fitnessVal = fitness(best_position)
  a=best_position
  v=np.array(a)
  x=v.reshape(4,18)

  km=KMeans(n_clusters=4,init=x, n_init=1)
  d=km.fit_predict(df)
  score = silhouette_score(df, km.labels_, metric='euclidean')





  #print(["%.6f"%best_position[k] for k in range(dim)])
  err = fitness(best_position)
  #print("fitness of best solution",err)
  df1 = pd.DataFrame(d);
  df = pd.DataFrame(df);
  df["Predicted"]=df1.values
  df["Actual"]=df2.values
  

  List=[parameter1,parameter2,"%s"%(filename),"after",completeness_score(d,Arr),homogeneity_score(d, Arr),rand_score(d, Arr),normalized_mutual_info_score(d, Arr)]
  with open('GGWWOO.csv', 'a') as f_object:

    writer_object = writer(f_object)
    writer_object.writerow(List)
    f_object.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# swarm  0.008498902125531177
# (72,)
# silhouette score is 0.17812960420815369
# inter 520731.78135723434
# intra 0.0
# x [0.0]
# inter 11288.7404958748
# intra 0.0057450426509851734
# inter 8831.046023489665
# intra 0.002551326252365489
# inter 19799.342529101377
# intra 0.0006775342839671265
# y [0.0057450426509851734]
# z [0.002551326252365489]
# swarm  0.00897390318731779
# (72,)
# silhouette score is 0.17555372563576366
# inter 17458.32936149234
# intra 0.0038374943355354353
# x [0.0038374943355354353]
# inter 76563.26264019465
# intra 0.0
# inter 31271.801133638208
# intra 3.7075353056557195e-05
# inter 11288.7404958748
# intra 0.0057450426509851734
# y [0
# inter 17458.32936149234
# intra 0.0038374943355354353
# inter 31271.801133638208
# intra 3.7075353056557195e-05
# y [0.0]
# z [0.0038374943355354353]
# swarm  0.009619612339577166
# (72,)
# silhouette score is 0.19570309118602863
# inter 520731.78135723434
# intra 0.0
# x [0.0]
# inter 6901.151877358458
# intra 0.0033969265650169943
# inter 164574.6318992852
# intra 0.0
# inter 8471.18228355769
# intra 0.010422755226680052
# y [0.0033969265650169943]
# z [0.0]
# swarm  0.013819681791697047
# (72,)
# silhouette score is 0.1466039743112853
# inter 14556.322888584225
# intra 0.0058421877078699445
# x [0.0058421877078699445]
# inter 337997.1634692785
# intra 0.0
# inter 10655.507748710026
# intra 0.00039049801909835525
# inter 11499.640747377454
# intra 0.002818047699671826
# y [0.0]
# z [0.00039049801909835525]
# swarm  0.009050733426640126
# (72,)
# silhouette score is 0.256601973471818
# inter 171246.66970403912
# intra 0.00010829477388866592
# x [0.00010829477388866592]
# inter 6882.571155468515
# intra 0.0015228021673807535
# inter 22397.35974184054
# intra 0.00035003090587766106
# inter 11288.7404958748
# intra 0.0057450426509851734
# y [0.0015228021673807535]
# z [0.00035003090587766106]
# swarm  0.007726170498132253
# (72,)
# silhouette score is 0.1139836380108125
# inter 5275.944655348247
# intra 0.035980775194669995
# x [0.035980775194669995]
# inter 337997.1634692785
# intra 0.0
# inter 118726.70978260794
# intra 0.0
# inter 134876.85126422913
# intra 0.0
# y [0.0]
# z [0.0]
# swarm  0.035980775194669995
# (72,)
# silhouette score is 0.27805423822058073
# inter 337997.1634692785
# intra 0.0
# x [0.0]
# inter 7849.91125244322
# intra 0.004311376884118081
# inter 22397.35974184054
# intra 0.00035003090587766106
# inter 17458.32936149234
# intra 0.0038374943355354353
# y [0.004311376884118081]
# z [0.00035003090587766106]
# swarm  0.008498902125531178
# (72,)
# silhouette score is 0.15466163566952887
# inter 5890.25056696306
# intra 0.006229886556719997
# x [0.006229886556719997]
# inter 5293.801160849153
# intra 0.0019910118589469886
# inter 65678.5775203731
# intra 0.00047859882509542064
# inter 85500.36659926837
# intra 0.0003770704595774594
# y [0.0019910118589469886]
# z [0.00047859882509542064]
# swarm  0.009076567700339867
# (72,)
# silhouette score is 0.27805423822058073
# inter 17458.32936149234
# intra 0.0038374943355354353
# x [0.0038374943355354353]
# inter 337997.1634692785
# intra 0.0
# inter 7849.91125244322
# intra 0.004311376884118081
# inter 22397.35974184054
# intra 0.00035003090587766106
# y [0.0]
# z [0.004311376884118081]
# swarm  0.008498902125531177
# (72,)
# silhouette score is 0.27805423822058073
# inter 22397.35974184054
# intra 0.00035003090587766106
# x [0.00035003090587766106]
# inter 337997.1634692785
# intra 0.0
# inter 7849.91125244322
# intra 0.004311376884118081
# inter 17458.32936149234
# intra 0.0038374943355354353
# y [0.0]
# z [0.004311376884118081]
# swarm  0.008498902125531178
# (72,)
# silhouette score is 0.05397919560967774
# inter 171246.66970403912
# intra 0.00010829477388866592
# x [0.00010829477388866592]
# inter 16077.587402590523
# intra 0.0007024929618701431
# inter 6876.625627273865
# intra 0.003294268120137647
# inter 12181.127334069432
# intra 0.006130910661400699
# y [0.0007024929618701431]
# z [0.003294268120137647]
# swarm  0.010235966517297156
# (72,)
# silhouette score is 0.12647720660132156
# inter 171246.66970403912
# intra 0.00010829477388866592
# x [0.00010829477388866592]
# inter 8471.18228355769
# intra 0.010422755226680052
# inter 84931.5751486347
# intra 0.0
# inter 6553.867321163333
# intra 0.002278133374733052
# y [0.010422755226680052]
# z [0.0]
# swarm  0.01280918337530177
# (72,)
# silhouette score is 0.19570309118602863
# inter 8471.18228355769
# intra 0.010422755226680052
# x [0.010422755226680052]
# inter 520731.78135723434
# intra 0.0
# inter 164574.6318992852
# intra 0.0
# inter 6901.151877358458
# intra 0.0033969265650169943
# y [0.0]
# z [0.0]
# swarm  0.013819681791697047
# (72,)
# silhouette score is 0.0959354097344208
# inter 337997.1634692785
# intra 0.0
# x [0.0]
# inter 4766.22380240082
# intra 0.01805041705114529
# inter 85500.36659926837
# intra 0.0003770704595774594
# inter 10655.507748710026
# intra 0.00039049801909835525
# y [0.01805041705114529]
# z [0.0003770704595774594]
# swarm  0.018817985529821103
# (72,)
# silhouette score is 0.19570309118602863
# inter 164574.6318992852
# intra 0.0
# x [0.0]
# inter 520731.78135723434
# intra 0.0
# inter 6901.151877358458
# intra 0.0033969265650169943
# inter 8471.18228355769
# intra 0.010422755226680052
# y [0.0]
# z [0.0033969265650169943]
# swarm  0.013819681791697047
# (72,)
# silhouette score is 0.19570309118602863
# inter 8471.18228355769
# intra 0.010422755226680052
# x [0.010422755226680052]
# inter 520731.78135723434
# intra 0.0
# inter 164574.6318992852
# intra 0.0
# inter 6901.151877358458
# intra 0.0033969265650169943
# y [0.0]
# z [0.0]
# swarm  0.013819681791697047
# (72,)
# silhouette score is 0.28817373947010005
# inter 520731.78135723434
# intra 0.0
# x [0.0]
# inter 11288.7404958748
# intra 0.0057450426509851734
# inter 22397.35974184054
# intra 0.00035003090587766106
# inter 9318.23333102966
# intra 0.002280345364405516
# y [0.0057450426509851734]
# z [0.00035003090587766106]
# swarm  0.00837541892126835
# (72,)
# silhouette score is 0.256601973471818
# inter 6882.571155468515
# intra 0.0015228021673807535
# x [0.0015228021673807535]
# inter 22397.35974184054
# intra 0.00035003090587766106
# inter 171246.66970403912
# intra 0.00010829477388866592
# inter 11288.7404958748
# intra 0.0057450426509851734
# y [0.00035003090587766106]
# z [0.00010829477388866592]
# swarm  0.007726170498132253
# (72,)
# silhouette score is 0.27805423822058073
# inter 337997.1634692785
# intra 0.0
# x [0.0]
# inter 7849.91125244322
# intra 0.004311376884118081
# inter 17458.32936149234
# intra 0.0038374943355354353
# inter 22397.35974184054
# intra 0.00035003090587766106
# y [0.004311376884118081]
# z [0.0038374943355354353]
# swarm  0.008498902125531177
# (72,)
# silhouette score is 0.2825039006600679
# inter 8400.817365333758
# intra 0.004312063861805854
# x [0.004312063861805854]
# inter 337997.1634692785
# intra 0.0
# inter 520731.78135723434
# intra 0.0
# inter 6286.719844004234
# intra 0.008326854503179328
# y [0.0]
# z [0.0]
# swarm  0.012638918364985182
# (72,)
# silhouette score is 0.20315164677795725
# inter 63338.646001247296
# intra 8.61336757269715e-05
# x [8.61336757269715e-05]
# inter 85500.36659926837
# intra 0.0003770704595774594
# inter 3149.0595839550747
# intra 0.019203631247908606
# inter 94446.0866252048
# intra 0.0001695142418264572
# y [0.0003770704595774594]
# z [0.019203631247908606]
# swarm  0.019836349625039496
# (72,)
# silhouette score is 0.1796312517219639
# inter 27115.414239955968
# intra 0.0010722069143953817
# x [0.0010722069143953817]
# inter 134876.85126422913
# intra 0.0
# inter 17458.32936149234
# intra 0.0038374943355354353
# inter 9913.397884894302
# intra 0.003363719306082472
# y [0.0]
# z [0.0038374943355354353]
# swarm  0.00827342055601329
# (72,)
# silhouette score is 0.2735861970730002
# inter 520731.78135723434
# intra 0.0
# x [0.0]
# inter 337997.1634692785
# intra 0.0
# inter 9318.23333102966
# intra 0.002280345364405516
# inter 5855.595032083719
# intra 0.011931514020122441
# y [0.0]
# z [0.002280345364405516]
# swarm  0.014211859384527957
# (72,)
# silhouette score is 0.1073069471552351
# inter 337997.1634692785
# intra 0.0
# x [0.0]
# inter 50369.34351627079
# intra 0.0008575286569900989
# inter 10655.507748710026
# intra 0.00039049801909835525
# inter 5402.509553341646
# intra 0.013745091837955453
# y [0.0008575286569900989]
# z [0.00039049801909835525]
# swarm  0.014993118514043906
# (72,)
# silhouette score is 0.1139836380108125
# inter 337997.1634692785
# intra 0.0
# x [0.0]
# inter 118726.70978260794
# intra 0.0
# inter 134876.85126422913
# intra 0.0
# inter 5275.944655348247
# intra 0.035980775194669995
# y [0.0]
# z [0.0]
# swarm  0.035980775194669995
# (72,)
# silhouette score is 0.1139836380108125
# inter 5275.944655348247
# intra 0.035980775194669995
# x [0.035980775194669995]
# inter 337997.1634692785
# intra 0.0
# inter 118726.70978260794
# intra 0.0
# inter 134876.85126422913
# intra 0.0
# y [0.0]
# z [0.0]
# swarm  0.035980775194669995
# (72,)
# silhouette score is 0.1139836380108125
# inter 337997.1634692785
# intra 0.0
# x [0.0]
# inter 118726.70978260794
# intra 0.0
# inter 134876.85126422913
# intra 0.0
# inter 5275.944655348247
# intra 0.035980775194669995
# y [0.0]
# z [0.0]
# swarm  0.035980775194669995
# (72,)
# silhouette score is 0.19069175334239433
# inter 6616.827455076483
# intra 0.010850463045655259
# x [0.010850463045655259]
# inter 63338.646001247296
# intra 8.61336757269715e-05
# inter 520731.78135723434
# intra 0.0
# inter 13063.960578373211
# intra 0.0032052186268961844
# y [8.61336757269715e-05]
# z [0.0]
# swarm  0.014141815348278415
# (72,)
# silhouette score is 0.2825039006600679
# inter 8400.817365333758
# intra 0.004312063861805854
# x [0.004312063861805854]
# inter 337997.1634692785
# intra 0.0
# inter 6286.719844004234
# intra 0.008326854503179328
# inter 520731.78135723434
# intra 0.0
# y [0.0]
# z [0.008326854503179328]
# swarm  0.012638918364985182
# (72,)
# silhouette score is 0.28817373947010005
# inter 9318.23333102966
# intra 0.002280345364405516
# x [0.002280345364405516]
# inter 520731.78135723434
# intra 0.0
# inter 11288.7404958748
# intra 0.0057450426509851734
# inter 22397.35974184054
# intra 0.00035003090587766106
# y [0.0]
# z [0.0057450426509851734]
# swarm  0.00837541892126835
# (72,)
# silhouette score is 0.09713996533127427
# inter 5618.1710512930795
# intra 0.020916855548049076
# x [0.020916855548049076]
# inter 76563.26264019465
# intra 0.0
# inter 85500.36659926837
# intra 0.0003770704595774594
# inter 31271.801133638208
# intra 3.7075353056557195e-05
# y [0.0]
# z [0.0003770704595774594]
# swarm  0.021331001360683093
# (72,)
# silhouette score is 0.20531726192878763
# inter 14556.322888584225
# intra 0.0058421877078699445
# x [0.0058421877078699445]
# inter 337997.1634692785
# intra 0.0
# inter 63338.646001247296
# intra 8.61336757269715e-05
# inter 5249.371749724456
# intra 0.005464320607651653
# y [0.0]
# z [8.61336757269715e-05]
# swarm  0.011392641991248568
# (72,)
# silhouette score is 0.2169805388098933
# inter 19799.342529101377
# intra 0.0006775342839671265
# x [0.0006775342839671265]
# inter 520731.78135723434
# intra 0.0
# inter 65678.5775203731
# intra 0.00047859882509542064
# inter 3528.396163062686
# intra 0.01507324729398304
# y [0.0]
# z [0.00047859882509542064]
# swarm  0.016229380403045588
# (72,)
# silhouette score is 0.28817373947010005
# inter 11288.7404958748
# intra 0.0057450426509851734
# x [0.0057450426509851734]
# inter 520731.78135723434
# intra 0.0
# inter 22397.35974184054
# intra 0.00035003090587766106
# inter 9318.23333102966
# intra 0.002280345364405516
# y [0.0]
# z [0.00035003090587766106]
# swarm  0.00837541892126835
# (72,)
# silhouette score is 0.17236313584977744
# inter 62305.30625649411
# intra 0.00010523078789692773
# x [0.00010523078789692773]
# inter 6553.867321163333
# intra 0.002278133374733052
# inter 520731.78135723434
# intra 0.0
# inter 8471.18228355769
# intra 0.010422755226680052
# y [0.002278133374733052]
# z [0.0]
# swarm  0.012806119389310032
# (72,)
# silhouette score is 0.17812960420815369
# inter 8831.046023489665
# intra 0.002551326252365489
# x [0.002551326252365489]
# inter 520731.78135723434
# intra 0.0
# inter 11288.7404958748
# intra 0.0057450426509851734
# inter 19799.342529101377
# intra 0.0006775342839671265
# y [0.0]
# z [0.0057450426509851734]
# swarm  0.00897390318731779
# (72,)
# silhouette score is 0.19570309118602863
# inter 164574.6318992852
# intra 0.0
# x [0.0]
# inter 520731.78135723434
# intra 0.0
# inter 6901.151877358458
# intra 0.0033969265650169943
# inter 8471.18228355769
# intra 0.010422755226680052
# y [0.0]
# z [0.0033969265650169943]
# swarm  0.013819681791697047
# (72,)
# silhouette score is 0.24865062051547834
# inter 17458.32936149234
# intra 0.0038374943355354353
# x [0.0038374943355354353]
# inter 27115.414239955968
# intra 0.0010722069143953817
# inter 22397.35974184054
# intra 0.00035003090587766106
# inter 18088.968851899892
# intra 0.0008188785582368315
# y [0.0010722069143953817]
# z [0.00035003090587766106]
# (72,)
# silhouette score is 0.24865062051547834
# inter 17458.32936149234
# intra 0.0038374943355354353
# x [0.0038374943355354353]
# inter 27115.414239955968
# intra 0.0010722069143953817
# inter 22397.35974184054
# intra 0.00035003090587766106
# inter 18088.968851899892
# intra 0.0008188785582368315
# y [0.0010722069143953817]
# z [0.00035003090587766106]
