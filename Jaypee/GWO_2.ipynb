# %%
import numpy as np
import numpy.random as rand
from sklearn.metrics import silhouette_score
import copy
import pandas as pd
import matplotlib.pyplot as plt
from numpy import savetxt
from sklearn.metrics.cluster import homogeneity_score
from sklearn.metrics.cluster import rand_score
from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import completeness_score
from csv import writer

# %%
filename="dolphin_output.npy"
p1=[[60,10],[60,20],[61,20],[61,30],[61,50],[62,30],[63,40],[62,50],[63,60],[62,70]]

# %%
from sklearn.cluster import KMeans
def K_means_clustering(datapoint,s):
    a=s
    v=np.array(a)
    x=v.reshape(2,32)
    km=KMeans(n_clusters=2,init=x, n_init=1)
    km.fit(datapoint)
    #score = silhouette_score(datapoint, km.labels_, metric='euclidean')
    #print("silhouette score is",score)
    def ClusterIndicesNumpy(clustNum, labels_array):
      return np.where(labels_array == clustNum)
    cluster_2_records=datapoint[ClusterIndicesNumpy(1,km.labels_)]
    cluster_1_records=datapoint[ClusterIndicesNumpy(0,km.labels_)]

    
    return [cluster_1_records,cluster_2_records]

# %%
def fitnes_function(position):
    #Pass only position , pass data-set and then generate 
    #fitness_value=0.0
    x,y=K_means_clustering(df,position)
    fitness_value_x=intra_cluster(x)
    print("x",fitness_value_x)
    fitness_value_y=intra_cluster(y)
    #fitness_value_z=intra_cluster(z)
    print("y",fitness_value_y)
    #print("z",fitness_value_z)
    
    fitness_value=float(np.asarray(fitness_value_x))+float(np.asarray(fitness_value_y))
    print("final",fitness_value)
    return fitness_value

# %%
#pos:mean of the cluster
def intra_cluster(data_point):
    import numpy as np
    c=data_point
    #print("shape of data vector is",c.shape)
    e=c.transpose()
    #print(e.shape)
    m,n=e.shape
    #print(m)
    #print(n)
    #mean_c=e.mean()
    #print("mean of the cluster is",mean_c)
    #print("shape of the mean of the cluster is",mean_c.shape)
    s1=0
    #mean_cluster=0
    total_sum_data_vector=0
    for x in range(0,n):
        p=c[:][x]
        #print(p.shape)
        data_vector=p.reshape(m,1)
        #print("shape of data point of cluster",data_vector.shape)
        total_sum_data_vector+=data_vector
        #print("total sum of individual data vectors",total_sum_data_vector)
        #print("shape of total sum of individual data vectors",total_sum_data_vector.shape)
        mean_cluster=total_sum_data_vector/n
        #print("mean of each cluster",mean_cluster)
    for x in range(0,n):
        p=c[:][x]
        #print(p.shape)
        data_vector=p.reshape(m,1)
        #print("shape of data point of cluster",data_vector.shape)
        diff=(data_vector-mean_cluster)
        #print("difference of data point with cluster difference",diff.shape)
        s1+=np.dot(diff,diff.transpose())
        #print(s1)
    #print("shape of within cluster distance matrix",s1.shape)
    #print("final within cluster distance matrix",s1.shape)
    #print("sum of intra cluster distance that is Sw is",s1.trace())
    within=s1.trace()
    intra=within.reshape(1,1)
    inter=inter_cluster(data_point)
    res=within/inter
    #print("ratio of trace is",res)
    print("intra",float(np.asarray(res)))
    return [float(np.asarray(res))]

# %%
def inter_cluster(data_point):
    total_sum_data_vector=0
    c=data_point
    s1=0
    #print("shape of data vector of individual cluster is",c.shape)
    m,n=c.shape
    #print(m)
    #print(n)
    f=c.transpose()
    #print(f.shape)
    for x in range(0,n):
        p=f[:][x]
        #print(p.shape)
        data_vector=p.reshape(m,1)
        #print("shape of data point of cluster",data_vector.shape)
        total_sum_data_vector+=data_vector
        #print("total sum of individual data vectors",total_sum_data_vector)
        #print("shape of total sum of individual data vectors",total_sum_data_vector.shape)
        mean_cluster=total_sum_data_vector/n
        #print("mean of each cluster",mean_cluster)
        #print("mean of each cluster shape",mean_cluster.shape)
        mean_overall_cluster=data_point/m*n
        
        diff=(mean_cluster-mean_overall_cluster)
        #print("difference of individual cluster with overall difference",diff.shape)
        s1+=np.dot(diff,diff.transpose())
        #print(s1)
        #print("shape of within cluster distance matrix",s1.shape)
        #print("final inter cluster distance matrix",s1.shape)
    #print("sum of inter cluster distance that is Sb is",s1.trace())
        #print(s1.trace().shape)
    inter=s1.trace()
    inter.reshape(1,1)
    #return[inter]
    print("inter",float(np.asarray(inter)))
    return[float(np.asarray(inter))]

# %%
# wolf class
class wolf:
    import numpy.random as rand
    def __init__(self, fitness, dim,seed):
        
        #self.position=[0.0 for i in range(dim)]
        #print(self.position)
        x=df.shape[0]-2
        index=rand.randint(parameter1,size=2)
        value=df[index]
        print(value)
        
        a=value.flatten()
        print(a)
        
        '''for x in b:
            for val in x:
                b.append(val)'''
                
        self.position=a
        
        self.fitness = fitness(self.position)
        print("fitness is",self.fitness)

# %%
import numpy as np
import random

def gwo(fitness, max_iter, n, dim):
    rnd = random.Random(0)
    
    # create n random wolves
    population = [ wolf(fitness, dim,i) for i in range(n)]
    print("printing population",population[0].position)
    
    # On the basis of fitness values of wolves
    # sort the population in asc order
    
    population = sorted(population, key = lambda temp: temp.fitness)
    
    
 
    # best 3 solutions will be called as
    # alpha, beta and gaama
    alpha_wolf, beta_wolf, gamma_wolf = copy.copy(population[: 3])
    print("alpha is",alpha_wolf.position)
    print("beta wolf is",beta_wolf.position)
    print("gamma wolf is",gamma_wolf.position)
    
    
    Iter = 0
    while Iter < max_iter:
         
        
 
        # linearly decreased from 2 to 0
        a = 2*(1 - Iter/max_iter)
 
        # updating each population member with the help of best three members
        for i in range(n):
            
            print("poulation is",population[i].position)
            A1, A2, A3 = a * (2 * rnd.random() - 1), a * (
              2 * rnd.random() - 1), a * (2 * rnd.random() - 1)
            C1, C2, C3 = 2 * rnd.random(), 2*rnd.random(), 2*rnd.random()
            
            
            X1 = [0.0 for i in range(dim)]
            X2 = [0.0 for i in range(dim)]
            X3 = [0.0 for i in range(dim)]
            Xnew = [0.0 for i in range(dim)]
            print("Type of Xnew",type(Xnew))
            
            
            for j in range(dim):
                print("alpha type",type(alpha_wolf.position[j]))
                print("population",population[i].position[j])
                print("alpha",(alpha_wolf.position[j]))
                print("population type",type(population[i].position[j]))
                
                X1[j] = alpha_wolf.position[j] - A1 * abs(
                  C1*alpha_wolf.position[j] - population[i].position[j])
                X2[j] = beta_wolf.position[j] - A2 * abs(
                  C2 *beta_wolf.position[j] - population[i].position[j])
                X3[j] = gamma_wolf.position[j] - A3 * abs(
                  C3*gamma_wolf.position[j] - population[i].position[j])
                Xnew[j]+= X1[j] + X2[j] + X3[j]
                
            for j in range(dim):
                Xnew[j]/=3.0
             

            # fitness calculation of new solution
            fnew = fitness(Xnew)
 
            # greedy selection
            if fnew < population[i].fitness:
                population[i].position = Xnew
                population[i].fitness = fnew
                
        # On the basis of fitness values of wolves
        # sort the population in asc order
        population = sorted(population, key = lambda temp: temp.fitness)
 
        # best 3 solutions will be called as
        # alpha, beta and gaama
        alpha_wolf, beta_wolf, gamma_wolf = copy.copy(population[: 3])
        print("Iteration number is",Iter)
        Iter+= 1
    # end-while
 
    # returning the best solution
    return alpha_wolf.position
           
#----------------------------

# %%
for i in range(0,10):
  df= np.loadtxt(r"%s"%(filename))
  df=np.nan_to_num(df, nan=0)
  parameter1=p1[i][0];
  parameter2=p1[i][1];
  Arr=np.zeros(df.shape[0])
  Dolphin1=[50,35,13,39,59,4,15,21,9,31,60,48,37,1,46,16,24,16,29,19,41,56,12,52,5,38,22,30,54,44,36,17,45,53,34,15,43,11,46,15];
  Dolphin2=[49,58,6,10,14,55,57,20,2,7,18,23,61,32,42,28,8,27,26];
  Karate1=[13,20,5,6,1,4,3,17,7,11,12,22,18,8,2,14];
  Karate2=[29,32,25,28,26,24,27,30,10,34,9,33,19,31,21,16,23,15];
  for i in range(df.shape[0]):
     if(i in Karate1):
       Arr[i]=1;
     elif(i in Karate2):
       Arr[i]=2;
  df2=pd.DataFrame(Arr);
  df2.shape[0]
  dim =64
  fitness =fitnes_function
  num_particles =10
  max_iter =parameter2
  best_position =gwo(fitness, max_iter, num_particles, dim)
  a=best_position
  v=np.array(a)
  x=v.reshape(2,32)

  km=KMeans(n_clusters=2,init=x, n_init=1)
  d=km.fit_predict(df)
  score = silhouette_score(df, km.labels_, metric='euclidean')





  #print(["%.6f"%best_position[k] for k in range(dim)])
  err = fitness(best_position)
  #print("fitness of best solution",err)
  df1 = pd.DataFrame(d);
  df = pd.DataFrame(df);
  df["Predicted"]=df1.values
  df["Actual"]=df2.values
  

  List=[parameter1,parameter2,"%s"%(filename),"after",completeness_score(d,Arr),homogeneity_score(d, Arr),rand_score(d, Arr),normalized_mutual_info_score(d, Arr)]
  with open('GGWWOO.csv', 'a') as f_object:

    writer_object = writer(f_object)
    writer_object.writerow(List)
    f_object.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.6507407377244914
# alpha 0.0264923629026855
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.7804397275331835
# alpha 0.3693790909354382
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.0953117345988983
# alpha -0.0278303897509413
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.313606122590265
# alpha 0.786423104944486
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.7528309104490765
# alpha -0.29862822401279
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.249841885743102
# alpha 0.9719978995895123
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.0983393380207835
# alpha -0.3810260389094564
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.0135345293774493
# alpha -0.1443807535750609
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.4985304942229087
# alpha 0.3650733957638468
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.1359824577925236
# alpha -0.2820846108118177
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.2668326173556103
# alpha -1.2026353466763458
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.3246010839304888
# alpha -1.0671234360805406
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.4694021330789445
# alpha -2.492337467705815
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -3.580643569595578
# alpha -1.201350315726843
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.7740317581832656
# alpha -1.8172096478904531
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 3.365275458923929
# alpha -0.3303588590612848
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 6.050400059972279
# alpha -1.375676179952327
# population type <class 'numpy.float64'>
# inter 23356.7982167354
# intra 0.03167897292917993
# x [0.03167897292917993]
# inter 55607.83899240253
# intra 0.008846263155281297
# y [0.008846263155281297]
# final 0.04052523608446122
# poulation is [-2.16246964e-01  1.02271307e-01 -7.64472939e-02  2.65772152e-03
#  -1.97299401e-01 -3.04499908e-02  2.51622872e-01 -7.96930650e-02
#   5.30441476e-02  3.49666665e-02  2.69077518e-01 -2.44669585e-01
#  -1.43813202e-01  5.19260391e-02  2.45711517e-01  1.15500453e-01
#   2.29832944e-01  1.06900889e-01  4.19463158e-01 -3.37887034e-03
#   8.77346734e-01 -1.60463497e-01 -1.80784418e-01 -4.58959743e-01
#   3.58475496e-01  5.31544837e-02  5.21188325e-02  2.58113145e+00
#   2.76745466e+00  3.15984114e+00 -1.17907052e-01  3.08149479e+00
#  -5.88922781e-02 -4.32991766e-02 -2.26765950e-02 -1.18833499e-01
