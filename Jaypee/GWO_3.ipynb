# %%
import numpy as np
import numpy.random as rand
from sklearn.metrics import silhouette_score
import copy
import pandas as pd
import matplotlib.pyplot as plt
from numpy import savetxt
from sklearn.metrics.cluster import homogeneity_score
from sklearn.metrics.cluster import rand_score
from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import completeness_score
from csv import writer

# %%
filename="polbooks_output.npy"
p1=[[102,10],[102,20],[101,20],[101,30],[103,50],[102,30],[103,40],[104,50],[104,60],[105,70]]

# %%
from sklearn.cluster import KMeans
def K_means_clustering(datapoint,s):
    a=s
    v=np.array(a)
    x=v.reshape(3,32)
    km=KMeans(n_clusters=3,init=x, n_init=1)
    km.fit(datapoint)
    score = silhouette_score(datapoint, km.labels_, metric='euclidean')
    print("silhouette score is",score)
    def ClusterIndicesNumpy(clustNum, labels_array):
        return np.where(labels_array == clustNum)[0]
    cluster_1_records=datapoint[ClusterIndicesNumpy(0,km.labels_)]
    cluster_2_records=datapoint[ClusterIndicesNumpy(1,km.labels_)]
    cluster_3_records=datapoint[ClusterIndicesNumpy(2,km.labels_)]
    print(cluster_1_records)
    return [cluster_1_records,cluster_2_records,cluster_3_records]

# %%
def fitnes_function(position):
    #Pass only position , pass data-set and then generate 
    #fitness_value=0.0
    x,y,z=K_means_clustering(df,position)
    fitness_value_x=intra_cluster(x)
    print("x",fitness_value_x)
    fitness_value_y=intra_cluster(y)
    fitness_value_z=intra_cluster(z)
    print("y",fitness_value_y)
    print("z",fitness_value_z)
    
    fitness_value=float(np.asarray(fitness_value_x))+float(np.asarray(fitness_value_y))+float(np.asarray(fitness_value_z))
    print("final",fitness_value)
    return fitness_value

# %%
#pos:mean of the cluster
def intra_cluster(data_point):
    import numpy as np
    c=data_point
    #print("shape of data vector is",c.shape)
    e=c.transpose()
    #print(e.shape)
    m,n=e.shape
    #print(m)
    #print(n)
    #mean_c=e.mean()
    #print("mean of the cluster is",mean_c)
    #print("shape of the mean of the cluster is",mean_c.shape)
    s1=0
    #mean_cluster=0
    total_sum_data_vector=0
    for x in range(0,n):
        p=c[:][x]
        #print(p.shape)
        data_vector=p.reshape(m,1)
        #print("shape of data point of cluster",data_vector.shape)
        total_sum_data_vector+=data_vector
        #print("total sum of individual data vectors",total_sum_data_vector)
        #print("shape of total sum of individual data vectors",total_sum_data_vector.shape)
        mean_cluster=total_sum_data_vector/n
        #print("mean of each cluster",mean_cluster)
    for x in range(0,n):
        p=c[:][x]
        #print(p.shape)
        data_vector=p.reshape(m,1)
        #print("shape of data point of cluster",data_vector.shape)
        diff=(data_vector-mean_cluster)
        #print("difference of data point with cluster difference",diff.shape)
        s1+=np.dot(diff,diff.transpose())
        #print(s1)
    #print("shape of within cluster distance matrix",s1.shape)
    #print("final within cluster distance matrix",s1.shape)
    #print("sum of intra cluster distance that is Sw is",s1.trace())
    within=s1.trace()
    intra=within.reshape(1,1)
    ## To change
    inter=inter_cluster(data_point)
    res=within/inter
   #print("ratio of trace is",res)
    print("intra",float(np.asarray(res)))
    return [float(np.asarray(res))]

# %%
def inter_cluster(data_point):
    total_sum_data_vector=0
    c=data_point
    s1=0
    #print("shape of data vector of individual cluster is",c.shape)
    m,n=c.shape
    #print(m)
    #print(n)
    f=c.transpose()
    #print(f.shape)
    for x in range(0,n):
        p=f[:][x]
        #print(p.shape)
        data_vector=p.reshape(m,1)
        #print("shape of data point of cluster",data_vector.shape)
        total_sum_data_vector+=data_vector
        #print("total sum of individual data vectors",total_sum_data_vector)
        #print("shape of total sum of individual data vectors",total_sum_data_vector.shape)
        mean_cluster=total_sum_data_vector/n
        #print("mean of each cluster",mean_cluster)
        #print("mean of each cluster shape",mean_cluster.shape)
        mean_overall_cluster=data_point/m*n
        
        diff=(mean_cluster-mean_overall_cluster)
        #print("difference of individual cluster with overall difference",diff.shape)
        s1+=np.dot(diff,diff.transpose())
        #print(s1)
        #print("shape of within cluster distance matrix",s1.shape)
        #print("final inter cluster distance matrix",s1.shape)
    #print("sum of inter cluster distance that is Sb is",s1.trace())
        #print(s1.trace().shape)
    inter=s1.trace()
    inter.reshape(1,1)
    #return[inter]
    print("inter",float(np.asarray(inter)))
    return[float(np.asarray(inter))]

# %%
# wolf class
class wolf:
    import numpy.random as rand
    def __init__(self, fitness, dim,seed):
        
        #self.position=[0.0 for i in range(dim)]
        #print(self.position)
        
        index=rand.randint(16,size=3)
        value=df[index]
        print(value)
        
        a=value.flatten()
        print(a)
        
        '''for x in b:
            for val in x:
                b.append(val)'''
                
        self.position=a
        
        self.fitness = fitness(self.position)
        print("fitness is",self.fitness)

# %%
import numpy as np
import random

def gwo(fitness, max_iter, n, dim):
    rnd = random.Random(0)
    
    # create n random wolves
    population = [ wolf(fitness, dim,i) for i in range(n)]
    print("printing population",population[0].position)
    
    # On the basis of fitness values of wolves
    # sort the population in asc order
    
    population = sorted(population, key = lambda temp: temp.fitness)
    
    
 
    # best 3 solutions will be called as
    # alpha, beta and gaama
    alpha_wolf, beta_wolf, gamma_wolf = copy.copy(population[: 3])
    print("alpha is",alpha_wolf.position)
    print("beta wolf is",beta_wolf.position)
    print("gamma wolf is",gamma_wolf.position)
    
    
    Iter = 0
    while Iter < max_iter:
         
        
 
        # linearly decreased from 2 to 0
        a = 2*(1 - Iter/max_iter)
 
        # updating each population member with the help of best three members
        for i in range(n):
            
            print("poulation is",population[i].position)
            A1, A2, A3 = a * (2 * rnd.random() - 1), a * (
              2 * rnd.random() - 1), a * (2 * rnd.random() - 1)
            C1, C2, C3 = 2 * rnd.random(), 2*rnd.random(), 2*rnd.random()
            
            
            X1 = [0.0 for i in range(dim)]
            X2 = [0.0 for i in range(dim)]
            X3 = [0.0 for i in range(dim)]
            Xnew = [0.0 for i in range(dim)]
            print("Type of Xnew",type(Xnew))
            
            
            for j in range(dim):
                print("alpha type",type(alpha_wolf.position[j]))
                print("population",population[i].position[j])
                print("alpha",(alpha_wolf.position[j]))
                print("population type",type(population[i].position[j]))
                
                X1[j] = alpha_wolf.position[j] - A1 * abs(
                  C1*alpha_wolf.position[j] - population[i].position[j])
                X2[j] = beta_wolf.position[j] - A2 * abs(
                  C2 *beta_wolf.position[j] - population[i].position[j])
                X3[j] = gamma_wolf.position[j] - A3 * abs(
                  C3*gamma_wolf.position[j] - population[i].position[j])
                Xnew[j]+= X1[j] + X2[j] + X3[j]
                
            for j in range(dim):
                Xnew[j]/=3.0
             

            # fitness calculation of new solution
            fnew = fitness(Xnew)
            print("fnew",fnew)

            print("pop",population[i].fitness)
            # greedy selection
            if fnew < population[i].fitness:
                population[i].position = Xnew
                population[i].fitness = fnew
                
        # On the basis of fitness values of wolves
        # sort the population in asc order
        population = sorted(population, key = lambda temp: temp.fitness)
 
        # best 3 solutions will be called as
        # alpha, beta and gaama
        alpha_wolf, beta_wolf, gamma_wolf = copy.copy(population[: 3])
        print("Iteration number is",Iter)
        Iter+= 1
    # end-while
 
    # returning the best solution
    return alpha_wolf.position
           
#----------------------------

# %%
for i in range(0,10):
  df= np.loadtxt(r"%s"%(filename))
  df=np.nan_to_num(df, nan=0)
  parameter1=p1[i][0];
  parameter2=p1[i][1];
  Arr=np.zeros(df.shape[0])
  Polbooks1=[17,16,38,39,37,44,26,18,14,45,30,33,3,2,6,57,23,53,59,78,25,50,56,20,35,40,42,55,36,43,28,24,9,12,13,34,27,22,46,58,48,40,15,51,54,21,46]
  Polbooks2=[77,8,7,1,104,105,47,5,49,29,19,52,70]
  Polbooks3=[99,93,79,32,76,84,92,88,101,63,91,82,80,83,72,98,85,75,83,72,64,61,100,74,73,31,86,60,97,87,71,67,69,102,90,89,94,81,65,62,96,95,68,103,66]
  Highland1=[0,1,12,14]
  Highland2=[13,8,9,12,4]
  Highland3=[6,7,3,2,5,11,10]
  for i in range(df.shape[0]):
     if(i in Highland1):
       Arr[i]=1;
     elif(i in Highland2):
       Arr[i]=2;
     elif(i in Highland3):
       Arr[i]=3;
  df2=pd.DataFrame(Arr);
  
  dim =96
  fitness =fitnes_function
  num_particles =10
  max_iter =parameter2
  best_position =gwo(fitness, max_iter, num_particles, dim)
  a=best_position
  v=np.array(a)
  x=v.reshape(3,32)

  km=KMeans(n_clusters=3,init=x, n_init=1)
  d=km.fit_predict(df)
  score = silhouette_score(df, km.labels_, metric='euclidean')





  #print(["%.6f"%best_position[k] for k in range(dim)])
  err = fitness(best_position)
  #print("fitness of best solution",err)
  df1 = pd.DataFrame(d);
  df = pd.DataFrame(df);
  df["Predicted"]=df1.values
  df["Actual"]=df2.values
  

  List=[parameter1,parameter2,"%s"%(filename),"after",completeness_score(d,Arr),homogeneity_score(d, Arr),rand_score(d, Arr),normalized_mutual_info_score(d, Arr)]
  with open('GGWWOO.csv', 'a') as f_object:

    writer_object = writer(f_object)
    writer_object.writerow(List)
    f_object.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# alpha type <class 'numpy.float64'>
# population 0.20370159962374032
# alpha 0.40911715735811066
# population type <class 'numpy.float64'>
# silhouette score is 0.17955925292031327
# [[ 0.19634316  0.24513126  0.20617696 ...  3.7662197   1.62420727
#    0.19894493]
#  [-0.31124199 -0.32312881 -0.19656945 ... -2.27394848 -1.1258403
#    0.43515501]
#  [ 0.05643099  0.17294126  0.16763658 ... -2.80762519 -1.29103875
#   -0.07306733]
#  ...
#  [ 0.17458014  0.00402046 -0.03559406 ...  1.1622798  -1.11795633
#   -0.64154122]
#  [-0.01057308  0.02708716  0.05056748 ...  0.77954655  0.66745538
#    0.4746869 ]
#  [-0.10288283  0.01617853  0.04608113 ...  1.47290732  1.24319954
#    0.79064295]]
# inter 10333.08953924569
# intra 0.09867561838101647
# x [0.09867561838101647]
# inter 42140.48678699225
# intra 0.011483454873271732
# inter 122025.53114005306
# intra 0.004082711903410729
# y [0.011483454873271732]
# z [0.004082711903410729]
# final 0.11424178515769894
# fnew 0.11424178515769894
# pop 0.0826111674405169
# poulation is [-0.1296711854546156, -0.04928965413165088, 0.10571559191119184, 0.2689516945317877, 0.13711811573478722, 0.0982656422701984, 0.16311745329230795, -0.055245363316266616, 0.22475566724173712, -0.13476860603697158, -0.39920386612471903, 0.31391256242035565, 0.025036100907921938, 0.028722288909572253, -0.0336348160586751, 0.19071360279628577, 0.06337419738194043, 0.48450115615129175, -0.06014499928110559, 0.3908210481367203, -0.2996357917839718, -0.014902587576243671, 0.3727881358294836, 0.12069830481541821, 0.16229906608997755, 0.03990950147251471, 0.9162448962609581, 0.15715862732988425, 0.9071621054832889, 2.2899322204235957, 2.5983705800256387, 0.7161859731038874, 0.34297366062468965, -0.20638801693233552, 0.013202271868216195, 0.23390298421711764, -0.5341991123963475, 0.06468171451720377, 0.14184011223283696, -0.06084961509214415, 0.03062386958424727, 0.025848205093166526, -0.6414147021065468, -0.6634784683425975, -0.45356317318191675, -0.2870913880574255, -1.128358811550255, 0.12624770410000388, 0.29562786636550437, -0.31843582779159396, 0.2243345103259936, 0.5967545435794789, 0.35066422667856895, 0.19623860446057284, -0.3021561993962251, -0.03645742877417384, -0.1231935873162688, -0.012131008665061754, 0.4172466819673671, -0.17398188153550107, 0.025760381725036103, 0.4828506253218133, -5.9871275242134, 6.568295460007263, 0.14472024993123153, 0.13439948332955634, 0.13577965308529824, -0.1525961353764285, 0.19653298462176957, 0.1376081335747818, 0.2908904438601765, 0.0988306858123504, 0.3520189324251359, 0.08276879085868459, 0.047184945447330894, 0.007235154428515485, 0.20296066852606978, 0.14528992710269195, -0.266771850900007, 0.4708989405742277, 0.2770607171929879, -0.08088524958582725, 0.14072701562083584, 0.4235875164523799, -0.030836641669662972, 0.039787983225329136, -0.10405857768701372, 0.23861329696688424, 0.16869032257154573, 0.22582183642510065, 1.5994535461662736, 0.3837274294760296, 0.9582860872711643, 1.7540629842042914, 1.1936512230953396, -0.2146996733673842]
# Type of Xnew <class 'list'>
# alpha type <class 'numpy.float64'>
# population -0.1296711854546156
# alpha -0.4378405221462624
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.04928965413165088
# alpha -0.3258776256927523
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.10571559191119184
# alpha 0.1616101109362051
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.2689516945317877
# alpha -0.05576601890838395
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.13711811573478722
# alpha 0.10255171941376177
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.0982656422701984
# alpha 0.14984150691473969
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.16311745329230795
# alpha 0.029650599957019196
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.055245363316266616
# alpha -0.24324140976561467
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.22475566724173712
# alpha 0.30398865866921626
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.13476860603697158
# alpha -0.3675723033498963
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.39920386612471903
# alpha -0.8059556673404896
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.31391256242035565
# alpha -0.2978255168726764
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.025036100907921938
# alpha -0.011690086029393252
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.028722288909572253
# alpha -0.6202983804269059
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.0336348160586751
# alpha -0.39763010002023863
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.19071360279628577
# alpha -0.38688005211316384
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.06337419738194043
# alpha -0.0930983708241831
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.48450115615129175
# alpha 0.059986235304332336
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.06014499928110559
# alpha -0.2665803752123787
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.3908210481367203
# alpha -0.3451277852803815
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2996357917839718
# alpha -0.38751941768196857
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.014902587576243671
# alpha -0.014455429406016537
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.3727881358294836
# alpha 0.016496461635247695
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.12069830481541821
# alpha -0.32867560615544716
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.16229906608997755
# alpha -0.007798631432117289
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.03990950147251471
# alpha -0.22874061383707658
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.9162448962609581
# alpha -2.162005526137252
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.15715862732988425
# alpha -0.8549075838459742
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.9071621054832889
# alpha -2.3221812952145924
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 2.2899322204235957
# alpha -3.459390951578866
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 2.5983705800256387
# alpha -0.9155746986422465
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.7161859731038874
# alpha -0.09487779214629304
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.34297366062468965
# alpha 0.11296026162267765
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.20638801693233552
# alpha -0.09698611536582408
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.013202271868216195
# alpha 0.006915444841902117
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.23390298421711764
# alpha 0.20131931082750035
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.5341991123963475
# alpha -0.5744960742750547
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.06468171451720377
# alpha 0.06346093254717865
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.14184011223283696
# alpha 0.23610253329688255
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.06084961509214415
# alpha -0.2307748728293422
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.03062386958424727
# alpha -0.46772401716596995
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.025848205093166526
# alpha -0.09110515942267566
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.6414147021065468
# alpha -0.4063640478886199
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.6634784683425975
# alpha -0.6804694361805784
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.45356317318191675
# alpha -0.9164122829397175
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2870913880574255
# alpha -0.5599923104285213
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.128358811550255
# alpha -0.8557426013802477
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.12624770410000388
# alpha 0.028695607257061814
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.29562786636550437
# alpha 0.045011203068084225
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.31843582779159396
# alpha -0.3235968738671003
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.2243345103259936
# alpha -0.020276196282620118
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.5967545435794789
# alpha 0.3823483475556217
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.35066422667856895
# alpha 0.09592843639006747
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.19623860446057284
# alpha 0.15103687919409756
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.3021561993962251
# alpha -0.26377727880080964
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.03645742877417384
# alpha -0.028420651613127467
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.1231935873162688
# alpha -0.5201388095571667
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.012131008665061754
# alpha -0.23264593564341748
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.4172466819673671
# alpha -1.081510737551626
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.17398188153550107
# alpha -0.9431018145903405
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.025760381725036103
# alpha -1.7772928467049327
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.4828506253218133
# alpha -2.3331417686367337
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -5.9871275242134
# alpha -4.889384475321662
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 6.568295460007263
# alpha 6.123335697053906
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.14472024993123153
# alpha -0.08057155383956732
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.13439948332955634
# alpha 0.28542318156908214
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.13577965308529824
# alpha 0.014046032101221143
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.1525961353764285
# alpha -0.31413481396785503
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.19653298462176957
# alpha -0.08320618512665566
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.1376081335747818
# alpha 0.3680781693710527
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.2908904438601765
# alpha 0.4671813171546497
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.0988306858123504
# alpha -0.32072151170502244
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.3520189324251359
# alpha 0.462479108028375
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.08276879085868459
# alpha 0.057990895776602686
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.047184945447330894
# alpha 0.16605963567514262
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.007235154428515485
# alpha -0.5154703962949059
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.20296066852606978
# alpha 0.3895979170248817
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.14528992710269195
# alpha -0.7353745142458302
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.266771850900007
# alpha -0.7916772675087816
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.4708989405742277
# alpha 0.014848873346919792
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.2770607171929879
# alpha 0.23638709229405283
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.08088524958582725
# alpha -0.20087381508560428
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.14072701562083584
# alpha 0.47019698583943165
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.4235875164523799
# alpha 0.009467553752880034
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.030836641669662972
# alpha 0.38719253962662353
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.039787983225329136
# alpha 0.21687349392657387
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.10405857768701372
# alpha -0.4150259516002636
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.23861329696688424
# alpha -0.05195510393181609
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.16869032257154573
# alpha 0.3785709886719724
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.22582183642510065
# alpha 0.2945156589699775
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.5994535461662736
# alpha 1.6850380049798517
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.3837274294760296
# alpha 1.299894274422761
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.9582860872711643
# alpha 3.4231372609853445
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.7540629842042914
# alpha 5.035622211580795
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.1936512230953396
# alpha 1.6744796916502853
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2146996733673842
# alpha 0.40911715735811066
# population type <class 'numpy.float64'>
# silhouette score is 0.17955925292031327
# [[ 0.19634316  0.24513126  0.20617696 ...  3.7662197   1.62420727
#    0.19894493]
#  [-0.31124199 -0.32312881 -0.19656945 ... -2.27394848 -1.1258403
#    0.43515501]
#  [ 0.05643099  0.17294126  0.16763658 ... -2.80762519 -1.29103875
#   -0.07306733]
#  ...
#  [ 0.17458014  0.00402046 -0.03559406 ...  1.1622798  -1.11795633
#   -0.64154122]
#  [-0.01057308  0.02708716  0.05056748 ...  0.77954655  0.66745538
#    0.4746869 ]
#  [-0.10288283  0.01617853  0.04608113 ...  1.47290732  1.24319954
#    0.79064295]]
# inter 10333.08953924569
# intra 0.09867561838101647
# x [0.09867561838101647]
# inter 42140.48678699225
# intra 0.011483454873271732
# inter 122025.53114005306
# intra 0.004082711903410729
# y [0.011483454873271732]
# z [0.004082711903410729]
# final 0.11424178515769894
# fnew 0.11424178515769894
# pop 0.08512622270013462
# poulation is [-0.4601617904630558, -0.2970258655613283, 0.06768235212338856, 0.09506767105555014, 0.06841883345321333, 0.06534978111511346, 0.04173822218778034, -0.19222498092905507, 0.14818845609658185, -0.42139553747730957, -0.945182771806229, -0.0946502069947397, -0.014797969362917732, -0.46520072752602, -0.2813745055222104, -0.2413740045418149, -0.04754571135521115, 0.244386582172164, -0.28635559667853033, -0.068156924084354, -0.4611765523492177, -0.01709703033160286, 0.10523905742565313, -0.21677792734117063, 0.03762319321451515, -0.15547780136745937, -1.387727096939563, -0.5743269535268004, -1.4777303321264617, -1.9038653779998649, 0.7032368442083493, 0.3219831915732774, 0.09485343268740003, -0.11244573149380299, 0.006003561583263994, 0.07566456483905147, -0.5135972022749584, 0.04412731789484481, 0.08131817000206244, -0.24757939377669302, -0.32879377287655526, -0.032275305517926976, -0.3905957750160967, -0.6103366475433176, -0.7504884696533104, -0.6361210901351095, -0.7773053519816119, -0.006334059442982376, 0.1605083442603288, -0.2854211296174019, 0.13960980382618593, 0.2649817434856793, 0.03761474976032715, 0.05981269374399859, -0.229514735459034, -0.03855155381584246, -0.4225241441925103, -0.19362392067446058, -0.3201682814436522, -0.932336362488236, -1.3414637369553033, -1.19072503269091, -4.2432394147834716, 2.3774245465250265, -0.01595811498694676, 0.08053903285745584, 0.004343232855488248, -0.34482955848673064, 0.006740737249157099, 0.11211011612615063, 0.16388262916217264, -0.10289037705018937, 0.21598672175277164, 0.02999428491891695, 0.04571029361693435, -0.3737848026405457, 0.13297509044116493, -0.4066457444263835, -0.6688402307896048, 0.23696965356935243, 0.1636586034277312, -0.15951466582453666, 0.15794528499316263, 0.12387653583980036, 0.18646504344516432, 0.05842012210294748, -0.44321718373791813, -0.010993252473149417, 0.12339033531606138, 0.11813875681599413, 0.8449316591584327, 0.38566051789614386, 1.0482654358679364, 1.4326953363084065, 0.38320814541938036, 0.09824463640067278]
# Type of Xnew <class 'list'>
# alpha type <class 'numpy.float64'>
# population -0.4601617904630558
# alpha -0.4378405221462624
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2970258655613283
# alpha -0.3258776256927523
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.06768235212338856
# alpha 0.1616101109362051
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.09506767105555014
# alpha -0.05576601890838395
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.06841883345321333
# alpha 0.10255171941376177
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.06534978111511346
# alpha 0.14984150691473969
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.04173822218778034
# alpha 0.029650599957019196
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.19222498092905507
# alpha -0.24324140976561467
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.14818845609658185
# alpha 0.30398865866921626
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.42139553747730957
# alpha -0.3675723033498963
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.945182771806229
# alpha -0.8059556673404896
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.0946502069947397
# alpha -0.2978255168726764
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.014797969362917732
# alpha -0.011690086029393252
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.46520072752602
# alpha -0.6202983804269059
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2813745055222104
# alpha -0.39763010002023863
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2413740045418149
# alpha -0.38688005211316384
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.04754571135521115
# alpha -0.0930983708241831
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.244386582172164
# alpha 0.059986235304332336
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.28635559667853033
# alpha -0.2665803752123787
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.068156924084354
# alpha -0.3451277852803815
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.4611765523492177
# alpha -0.38751941768196857
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.01709703033160286
# alpha -0.014455429406016537
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.10523905742565313
# alpha 0.016496461635247695
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.21677792734117063
# alpha -0.32867560615544716
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.03762319321451515
# alpha -0.007798631432117289
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.15547780136745937
# alpha -0.22874061383707658
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.387727096939563
# alpha -2.162005526137252
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.5743269535268004
# alpha -0.8549075838459742
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.4777303321264617
# alpha -2.3221812952145924
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.9038653779998649
# alpha -3.459390951578866
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.7032368442083493
# alpha -0.9155746986422465
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.3219831915732774
# alpha -0.09487779214629304
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.09485343268740003
# alpha 0.11296026162267765
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.11244573149380299
# alpha -0.09698611536582408
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.006003561583263994
# alpha 0.006915444841902117
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.07566456483905147
# alpha 0.20131931082750035
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.5135972022749584
# alpha -0.5744960742750547
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.04412731789484481
# alpha 0.06346093254717865
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.08131817000206244
# alpha 0.23610253329688255
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.24757939377669302
# alpha -0.2307748728293422
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.32879377287655526
# alpha -0.46772401716596995
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.032275305517926976
# alpha -0.09110515942267566
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.3905957750160967
# alpha -0.4063640478886199
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.6103366475433176
# alpha -0.6804694361805784
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.7504884696533104
# alpha -0.9164122829397175
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.6361210901351095
# alpha -0.5599923104285213
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.7773053519816119
# alpha -0.8557426013802477
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.006334059442982376
# alpha 0.028695607257061814
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.1605083442603288
# alpha 0.045011203068084225
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2854211296174019
# alpha -0.3235968738671003
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.13960980382618593
# alpha -0.020276196282620118
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.2649817434856793
# alpha 0.3823483475556217
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.03761474976032715
# alpha 0.09592843639006747
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.05981269374399859
# alpha 0.15103687919409756
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.229514735459034
# alpha -0.26377727880080964
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.03855155381584246
# alpha -0.028420651613127467
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.4225241441925103
# alpha -0.5201388095571667
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.19362392067446058
# alpha -0.23264593564341748
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.3201682814436522
# alpha -1.081510737551626
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.932336362488236
# alpha -0.9431018145903405
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.3414637369553033
# alpha -1.7772928467049327
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.19072503269091
# alpha -2.3331417686367337
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -4.2432394147834716
# alpha -4.889384475321662
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 2.3774245465250265
# alpha 6.123335697053906
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.01595811498694676
# alpha -0.08057155383956732
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.08053903285745584
# alpha 0.28542318156908214
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.004343232855488248
# alpha 0.014046032101221143
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.34482955848673064
# alpha -0.31413481396785503
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.006740737249157099
# alpha -0.08320618512665566
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.11211011612615063
# alpha 0.3680781693710527
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.16388262916217264
# alpha 0.4671813171546497
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.10289037705018937
# alpha -0.32072151170502244
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.21598672175277164
# alpha 0.462479108028375
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.02999428491891695
# alpha 0.057990895776602686
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.04571029361693435
# alpha 0.16605963567514262
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.3737848026405457
# alpha -0.5154703962949059
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.13297509044116493
# alpha 0.3895979170248817
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.4066457444263835
# alpha -0.7353745142458302
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.6688402307896048
# alpha -0.7916772675087816
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.23696965356935243
# alpha 0.014848873346919792
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.1636586034277312
# alpha 0.23638709229405283
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.15951466582453666
# alpha -0.20087381508560428
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.15794528499316263
# alpha 0.47019698583943165
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.12387653583980036
# alpha 0.009467553752880034
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.18646504344516432
# alpha 0.38719253962662353
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.05842012210294748
# alpha 0.21687349392657387
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.44321718373791813
# alpha -0.4150259516002636
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.010993252473149417
# alpha -0.05195510393181609
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.12339033531606138
# alpha 0.3785709886719724
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.11813875681599413
# alpha 0.2945156589699775
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.8449316591584327
# alpha 1.6850380049798517
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.38566051789614386
# alpha 1.299894274422761
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.0482654358679364
# alpha 3.4231372609853445
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.4326953363084065
# alpha 5.035622211580795
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.38320814541938036
# alpha 1.6744796916502853
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.09824463640067278
# alpha 0.40911715735811066
# population type <class 'numpy.float64'>
# silhouette score is 0.17955925292031327
# [[ 0.19634316  0.24513126  0.20617696 ...  3.7662197   1.62420727
#    0.19894493]
#  [-0.31124199 -0.32312881 -0.19656945 ... -2.27394848 -1.1258403
#    0.43515501]
#  [ 0.05643099  0.17294126  0.16763658 ... -2.80762519 -1.29103875
#   -0.07306733]
#  ...
#  [ 0.17458014  0.00402046 -0.03559406 ...  1.1622798  -1.11795633
#   -0.64154122]
#  [-0.01057308  0.02708716  0.05056748 ...  0.77954655  0.66745538
#    0.4746869 ]
#  [-0.10288283  0.01617853  0.04608113 ...  1.47290732  1.24319954
#    0.79064295]]
# inter 10333.08953924569
# intra 0.09867561838101647
# x [0.09867561838101647]
# inter 42140.48678699225
# intra 0.011483454873271732
# inter 122025.53114005306
# intra 0.004082711903410729
# y [0.011483454873271732]
# z [0.004082711903410729]
# final 0.11424178515769894
# fnew 0.11424178515769894
# pop 0.08512622270013462
# Iteration number is 68
# poulation is [-0.4378405221462624, -0.3258776256927523, 0.1616101109362051, -0.05576601890838395, 0.10255171941376177, 0.14984150691473969, 0.029650599957019196, -0.24324140976561467, 0.30398865866921626, -0.3675723033498963, -0.8059556673404896, -0.2978255168726764, -0.011690086029393252, -0.6202983804269059, -0.39763010002023863, -0.38688005211316384, -0.0930983708241831, 0.059986235304332336, -0.2665803752123787, -0.3451277852803815, -0.38751941768196857, -0.014455429406016537, 0.016496461635247695, -0.32867560615544716, -0.007798631432117289, -0.22874061383707658, -2.162005526137252, -0.8549075838459742, -2.3221812952145924, -3.459390951578866, -0.9155746986422465, -0.09487779214629304, 0.11296026162267765, -0.09698611536582408, 0.006915444841902117, 0.20131931082750035, -0.5744960742750547, 0.06346093254717865, 0.23610253329688255, -0.2307748728293422, -0.46772401716596995, -0.09110515942267566, -0.4063640478886199, -0.6804694361805784, -0.9164122829397175, -0.5599923104285213, -0.8557426013802477, 0.028695607257061814, 0.045011203068084225, -0.3235968738671003, -0.020276196282620118, 0.3823483475556217, 0.09592843639006747, 0.15103687919409756, -0.26377727880080964, -0.028420651613127467, -0.5201388095571667, -0.23264593564341748, -1.081510737551626, -0.9431018145903405, -1.7772928467049327, -2.3331417686367337, -4.889384475321662, 6.123335697053906, -0.08057155383956732, 0.28542318156908214, 0.014046032101221143, -0.31413481396785503, -0.08320618512665566, 0.3680781693710527, 0.4671813171546497, -0.32072151170502244, 0.462479108028375, 0.057990895776602686, 0.16605963567514262, -0.5154703962949059, 0.3895979170248817, -0.7353745142458302, -0.7916772675087816, 0.014848873346919792, 0.23638709229405283, -0.20087381508560428, 0.47019698583943165, 0.009467553752880034, 0.38719253962662353, 0.21687349392657387, -0.4150259516002636, -0.05195510393181609, 0.3785709886719724, 0.2945156589699775, 1.6850380049798517, 1.299894274422761, 3.4231372609853445, 5.035622211580795, 1.6744796916502853, 0.40911715735811066]
# Type of Xnew <class 'list'>
# alpha type <class 'numpy.float64'>
# population -0.4378405221462624
# alpha -0.4378405221462624
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.3258776256927523
# alpha -0.3258776256927523
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.1616101109362051
# alpha 0.1616101109362051
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.05576601890838395
# alpha -0.05576601890838395
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.10255171941376177
# alpha 0.10255171941376177
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.14984150691473969
# alpha 0.14984150691473969
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.029650599957019196
# alpha 0.029650599957019196
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.24324140976561467
# alpha -0.24324140976561467
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.30398865866921626
# alpha 0.30398865866921626
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.3675723033498963
# alpha -0.3675723033498963
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.8059556673404896
# alpha -0.8059556673404896
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2978255168726764
# alpha -0.2978255168726764
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.011690086029393252
# alpha -0.011690086029393252
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.6202983804269059
# alpha -0.6202983804269059
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.39763010002023863
# alpha -0.39763010002023863
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.38688005211316384
# alpha -0.38688005211316384
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.0930983708241831
# alpha -0.0930983708241831
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.059986235304332336
# alpha 0.059986235304332336
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2665803752123787
# alpha -0.2665803752123787
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.3451277852803815
# alpha -0.3451277852803815
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.38751941768196857
# alpha -0.38751941768196857
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.014455429406016537
# alpha -0.014455429406016537
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.016496461635247695
# alpha 0.016496461635247695
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.32867560615544716
# alpha -0.32867560615544716
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.007798631432117289
# alpha -0.007798631432117289
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.22874061383707658
# alpha -0.22874061383707658
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -2.162005526137252
# alpha -2.162005526137252
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.8549075838459742
# alpha -0.8549075838459742
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -2.3221812952145924
# alpha -2.3221812952145924
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -3.459390951578866
# alpha -3.459390951578866
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.9155746986422465
# alpha -0.9155746986422465
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.09487779214629304
# alpha -0.09487779214629304
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.11296026162267765
# alpha 0.11296026162267765
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.09698611536582408
# alpha -0.09698611536582408
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.006915444841902117
# alpha 0.006915444841902117
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.20131931082750035
# alpha 0.20131931082750035
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.5744960742750547
# alpha -0.5744960742750547
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.06346093254717865
# alpha 0.06346093254717865
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.23610253329688255
# alpha 0.23610253329688255
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2307748728293422
# alpha -0.2307748728293422
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.46772401716596995
# alpha -0.46772401716596995
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.09110515942267566
# alpha -0.09110515942267566
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.4063640478886199
# alpha -0.4063640478886199
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.6804694361805784
# alpha -0.6804694361805784
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.9164122829397175
# alpha -0.9164122829397175
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.5599923104285213
# alpha -0.5599923104285213
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.8557426013802477
# alpha -0.8557426013802477
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.028695607257061814
# alpha 0.028695607257061814
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.045011203068084225
# alpha 0.045011203068084225
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.3235968738671003
# alpha -0.3235968738671003
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.020276196282620118
# alpha -0.020276196282620118
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.3823483475556217
# alpha 0.3823483475556217
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.09592843639006747
# alpha 0.09592843639006747
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.15103687919409756
# alpha 0.15103687919409756
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.26377727880080964
# alpha -0.26377727880080964
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.028420651613127467
# alpha -0.028420651613127467
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.5201388095571667
# alpha -0.5201388095571667
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.23264593564341748
# alpha -0.23264593564341748
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.081510737551626
# alpha -1.081510737551626
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.9431018145903405
# alpha -0.9431018145903405
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.7772928467049327
# alpha -1.7772928467049327
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -2.3331417686367337
# alpha -2.3331417686367337
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -4.889384475321662
# alpha -4.889384475321662
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 6.123335697053906
# alpha 6.123335697053906
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.08057155383956732
# alpha -0.08057155383956732
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.28542318156908214
# alpha 0.28542318156908214
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.014046032101221143
# alpha 0.014046032101221143
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.31413481396785503
# alpha -0.31413481396785503
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.08320618512665566
# alpha -0.08320618512665566
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.3680781693710527
# alpha 0.3680781693710527
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.4671813171546497
# alpha 0.4671813171546497
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.32072151170502244
# alpha -0.32072151170502244
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.462479108028375
# alpha 0.462479108028375
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.057990895776602686
# alpha 0.057990895776602686
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.16605963567514262
# alpha 0.16605963567514262
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.5154703962949059
# alpha -0.5154703962949059
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.3895979170248817
# alpha 0.3895979170248817
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.7353745142458302
# alpha -0.7353745142458302
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.7916772675087816
# alpha -0.7916772675087816
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.014848873346919792
# alpha 0.014848873346919792
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.23638709229405283
# alpha 0.23638709229405283
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.20087381508560428
# alpha -0.20087381508560428
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.47019698583943165
# alpha 0.47019698583943165
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.009467553752880034
# alpha 0.009467553752880034
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.38719253962662353
# alpha 0.38719253962662353
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.21687349392657387
# alpha 0.21687349392657387
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.4150259516002636
# alpha -0.4150259516002636
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.05195510393181609
# alpha -0.05195510393181609
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.3785709886719724
# alpha 0.3785709886719724
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.2945156589699775
# alpha 0.2945156589699775
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.6850380049798517
# alpha 1.6850380049798517
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.299894274422761
# alpha 1.299894274422761
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 3.4231372609853445
# alpha 3.4231372609853445
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 5.035622211580795
# alpha 5.035622211580795
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.6744796916502853
# alpha 1.6744796916502853
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.40911715735811066
# alpha 0.40911715735811066
# population type <class 'numpy.float64'>
# silhouette score is 0.17955925292031327
# [[ 0.19634316  0.24513126  0.20617696 ...  3.7662197   1.62420727
#    0.19894493]
#  [-0.31124199 -0.32312881 -0.19656945 ... -2.27394848 -1.1258403
#    0.43515501]
#  [ 0.05643099  0.17294126  0.16763658 ... -2.80762519 -1.29103875
#   -0.07306733]
#  ...
#  [ 0.17458014  0.00402046 -0.03559406 ...  1.1622798  -1.11795633
#   -0.64154122]
#  [-0.01057308  0.02708716  0.05056748 ...  0.77954655  0.66745538
#    0.4746869 ]
#  [-0.10288283  0.01617853  0.04608113 ...  1.47290732  1.24319954
#    0.79064295]]
# inter 10333.08953924569
# intra 0.09867561838101647
# x [0.09867561838101647]
# inter 42140.48678699225
# intra 0.011483454873271732
# inter 122025.53114005306
# intra 0.004082711903410729
# y [0.011483454873271732]
# z [0.004082711903410729]
# final 0.11424178515769894
# fnew 0.11424178515769894
# pop 0.07500450100738301
# ...
# Type of Xnew <class 'list'>
# alpha type <class 'numpy.float64'>
# population -0.4601617904630558
# alpha -0.4378405221462624
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2970258655613283
# alpha -0.3258776256927523
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.06768235212338856
# alpha 0.1616101109362051
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.09506767105555014
# alpha -0.05576601890838395
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.06841883345321333
# alpha 0.10255171941376177
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.06534978111511346
# alpha 0.14984150691473969
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.04173822218778034
# alpha 0.029650599957019196
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.19222498092905507
# alpha -0.24324140976561467
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.14818845609658185
# alpha 0.30398865866921626
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.42139553747730957
# alpha -0.3675723033498963
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.945182771806229
# alpha -0.8059556673404896
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.0946502069947397
# alpha -0.2978255168726764
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.014797969362917732
# alpha -0.011690086029393252
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.46520072752602
# alpha -0.6202983804269059
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2813745055222104
# alpha -0.39763010002023863
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2413740045418149
# alpha -0.38688005211316384
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.04754571135521115
# alpha -0.0930983708241831
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.244386582172164
# alpha 0.059986235304332336
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.28635559667853033
# alpha -0.2665803752123787
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.068156924084354
# alpha -0.3451277852803815
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.4611765523492177
# alpha -0.38751941768196857
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.01709703033160286
# alpha -0.014455429406016537
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.10523905742565313
# alpha 0.016496461635247695
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.21677792734117063
# alpha -0.32867560615544716
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.03762319321451515
# alpha -0.007798631432117289
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.15547780136745937
# alpha -0.22874061383707658
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.387727096939563
# alpha -2.162005526137252
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.5743269535268004
# alpha -0.8549075838459742
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.4777303321264617
# alpha -2.3221812952145924
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.9038653779998649
# alpha -3.459390951578866
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.7032368442083493
# alpha -0.9155746986422465
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.3219831915732774
# alpha -0.09487779214629304
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.09485343268740003
# alpha 0.11296026162267765
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.11244573149380299
# alpha -0.09698611536582408
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.006003561583263994
# alpha 0.006915444841902117
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.07566456483905147
# alpha 0.20131931082750035
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.5135972022749584
# alpha -0.5744960742750547
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.04412731789484481
# alpha 0.06346093254717865
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.08131817000206244
# alpha 0.23610253329688255
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.24757939377669302
# alpha -0.2307748728293422
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.32879377287655526
# alpha -0.46772401716596995
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.032275305517926976
# alpha -0.09110515942267566
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.3905957750160967
# alpha -0.4063640478886199
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.6103366475433176
# alpha -0.6804694361805784
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.7504884696533104
# alpha -0.9164122829397175
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.6361210901351095
# alpha -0.5599923104285213
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.7773053519816119
# alpha -0.8557426013802477
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.006334059442982376
# alpha 0.028695607257061814
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.1605083442603288
# alpha 0.045011203068084225
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.2854211296174019
# alpha -0.3235968738671003
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.13960980382618593
# alpha -0.020276196282620118
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.2649817434856793
# alpha 0.3823483475556217
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.03761474976032715
# alpha 0.09592843639006747
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.05981269374399859
# alpha 0.15103687919409756
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.229514735459034
# alpha -0.26377727880080964
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.03855155381584246
# alpha -0.028420651613127467
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.4225241441925103
# alpha -0.5201388095571667
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.19362392067446058
# alpha -0.23264593564341748
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.3201682814436522
# alpha -1.081510737551626
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.932336362488236
# alpha -0.9431018145903405
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.3414637369553033
# alpha -1.7772928467049327
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -1.19072503269091
# alpha -2.3331417686367337
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -4.2432394147834716
# alpha -4.889384475321662
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 2.3774245465250265
# alpha 6.123335697053906
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.01595811498694676
# alpha -0.08057155383956732
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.08053903285745584
# alpha 0.28542318156908214
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.004343232855488248
# alpha 0.014046032101221143
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.34482955848673064
# alpha -0.31413481396785503
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.006740737249157099
# alpha -0.08320618512665566
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.11211011612615063
# alpha 0.3680781693710527
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.16388262916217264
# alpha 0.4671813171546497
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.10289037705018937
# alpha -0.32072151170502244
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.21598672175277164
# alpha 0.462479108028375
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.02999428491891695
# alpha 0.057990895776602686
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.04571029361693435
# alpha 0.16605963567514262
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.3737848026405457
# alpha -0.5154703962949059
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.13297509044116493
# alpha 0.3895979170248817
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.4066457444263835
# alpha -0.7353745142458302
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.6688402307896048
# alpha -0.7916772675087816
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.23696965356935243
# alpha 0.014848873346919792
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.1636586034277312
# alpha 0.23638709229405283
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.15951466582453666
# alpha -0.20087381508560428
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.15794528499316263
# alpha 0.47019698583943165
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.12387653583980036
# alpha 0.009467553752880034
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.18646504344516432
# alpha 0.38719253962662353
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.05842012210294748
# alpha 0.21687349392657387
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.44321718373791813
# alpha -0.4150259516002636
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population -0.010993252473149417
# alpha -0.05195510393181609
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.12339033531606138
# alpha 0.3785709886719724
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.11813875681599413
# alpha 0.2945156589699775
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.8449316591584327
# alpha 1.6850380049798517
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.38566051789614386
# alpha 1.299894274422761
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.0482654358679364
# alpha 3.4231372609853445
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 1.4326953363084065
# alpha 5.035622211580795
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.38320814541938036
# alpha 1.6744796916502853
# population type <class 'numpy.float64'>
# alpha type <class 'numpy.float64'>
# population 0.09824463640067278
# alpha 0.40911715735811066
# population type <class 'numpy.float64'>
# silhouette score is 0.17955925292031327
# [[ 0.19634316  0.24513126  0.20617696 ...  3.7662197   1.62420727
#    0.19894493]
#  [-0.31124199 -0.32312881 -0.19656945 ... -2.27394848 -1.1258403
#    0.43515501]
#  [ 0.05643099  0.17294126  0.16763658 ... -2.80762519 -1.29103875
#   -0.07306733]
#  ...
#  [ 0.17458014  0.00402046 -0.03559406 ...  1.1622798  -1.11795633
#   -0.64154122]
#  [-0.01057308  0.02708716  0.05056748 ...  0.77954655  0.66745538
#    0.4746869 ]
#  [-0.10288283  0.01617853  0.04608113 ...  1.47290732  1.24319954
#    0.79064295]]
# inter 10333.08953924569
# intra 0.09867561838101647
# x [0.09867561838101647]
# inter 42140.48678699225
# intra 0.011483454873271732
# inter 122025.53114005306
# intra 0.004082711903410729
# y [0.011483454873271732]
# z [0.004082711903410729]
# final 0.11424178515769894
# fnew 0.11424178515769894
# pop 0.08512622270013462
# Iteration number is 69
# silhouette score is 0.2430201529954319
# [[ 1.13454468e-01 -3.01392881e-01  3.36912717e-01 ... -1.51225050e+00
#   -5.41991145e+00 -6.20435232e+00]
#  [-8.99807116e-02  3.13130515e-01  2.18108103e-01 ... -1.39893867e+00
#   -2.89838190e+00 -3.38437945e+00]
#  [ 2.82893755e-02  1.17513640e-01 -1.12488530e-01 ...  2.69329988e+00
#   -1.10069138e+00 -1.82642205e+00]
#  ...
#  [ 2.83663586e-01 -1.02828746e-02  2.87687269e-01 ...  1.90417483e+00
#   -3.29851039e+00 -4.57071741e+00]
#  [-1.62795781e-01  1.96565154e-01  2.11475155e-01 ...  1.48719029e+00
#   -1.30354559e+00 -1.82186132e+00]
#  [ 1.74580135e-01  4.02046497e-03 -3.55940559e-02 ...  1.16227980e+00
#   -1.11795633e+00 -6.41541217e-01]]
# inter 26125.080798225885
# intra 0.03173036782566503
# x [0.03173036782566503]
# inter 20641.545342995138
# intra 0.03635291714357356
# inter 68316.8013124668
# intra 0.006921216038144417
# y [0.03635291714357356]
# z [0.006921216038144417]
# final 0.07500450100738301
